# %%
#%pip install --upgrade hyperspectral_gta_data

# %%
# Common useful packages
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import copy
import spectral
from sklearn import linear_model

# module that is useful for reloading packages
import importlib

# Scripts associated with the SML4SI textbook
import hyperspectral_gta_data as hsi_data
import scripts_M2 as sm2

# set the directory where data will be downloaded and accessed
# (This directory will be saved in a config file and used each time you use hyperspectral_gta_data, 
# so you don't need to run the 'set_data_dir' function every time you use hyperspectral_gta_data.)
hsi_data.set_data_dir('C:/spectral_data')

# %% [markdown]
# ## In this notebook, we will introduce unmixing a hyperspectral image using a spectral library
#
# With target detection, we have two data sets:
# 1. **A hyperspectral image.**
# 2. **A spectral library.**
#
# The spectral library are usually collected from known materials that we believe are likely to be present in .
#
# The data preparation is the same as for taarget detection, which includes:
# 1. **Load Data:** Load the image and spectral library.
# 2. **Check Data Scale:** Check that the iamge and library have the same scale. Ideally, they are both on a 0-1 scale for reflectance units, but:
#     i. Sometimes data are stored in 16-bit integer data type to save memory and resources.  In that case, they are often on a 0-1000 scale.
#     ii. Often, the values for spectral data are too large or small due to (1) changes in sunlight and shadow, (2) problems in atmospherice correction, converting from radiance to reflectance, or (3) calibration of sensors.
# 3. **Check Wavelengths:** Check that the image and spectra have wavelengths in the same units (both nanometers or both micrometers) and have the same values.  If the units are different, we simply multiply or divide by 1000 as needed.  If the wavelength values are different, we have to resample the data. Almost always, this means resampling the library to the wavelengths of the image, because the library usually has higher spectral resolution (more bands with more tightly-spaced wavelengths).
# 4. **Quality Check:** Do a quality check on the data and spectra.  If the light source for either is the sun, then there will be bands where the atmosphere (mostly water vapor) absorbs most of the light.  These need to be removed from the data, and then the resampling is needed as in Step 3.
#
# After these are completed, we will be ready for unmixing.

# %% [markdown]
# ## Data: Our data will be hyperspectral images over the Cuprite, Nevada area.  Below is known locaitons of minerals present at the surface in this area:
#
# ![image.png](attachment:image.png)
#
# Image from: https://www.usgs.gov/publications/mapping-advanced-argillic-alteration-cuprite-nevada-using-imaging-spectroscopy

# %% [markdown]
# # 1. Download the data

# %%
# Here are the datasets available through the hyperspectral_gta_data package
hsi_data.available_datasets()
# Out:
# Available Images:
#    WashingtonDC
#    MicroscenePolymers
#    DetectionImagery_CookeCity_RIT
#    VegBaccharisUPWINS
#    PaintDetectionUPWINS
#    indian_pines
#    pavia_centre
#    pavia_university
#    AVIRIS_Cuprite
#    ENMAP_Cuprite
# Available Spectral Libraries:
#    GHISACONUS_2008_001_speclib
#    Microscene_Polymers_Library
#    UPWINS_4_16_2024
#    Detection_Library_Cooke_City_RIT
#    USGS_splib07b

# %% [markdown]
# ## Download the hyperspectral image
#
# In this case, we will be using a hyperspectral image from the RIT test over Cooke City, Montana. (https://dirsapps.cis.rit.edu/blindtest/)

# %%
# Download and use the Cooke Cite image:
hsi_data.download('AVIRIS_Cuprite')
fname = hsi_data.get_fname('AVIRIS_Cuprite')
# Out:
# Available Files:
# C:\spectral_data\spectral_images\AVIRIS_Cuprite\AVIRIS_cuprite_ang20200712t201415_subset
# C:\spectral_data\spectral_images\AVIRIS_Cuprite\AVIRIS_cuprite_ang20200712t201415_subset.hdr
# Primary Image Filename:
# C:/spectral_data\spectral_images\AVIRIS_Cuprite/AVIRIS_cuprite_ang20200712t201415_subset

# %%
# load the Cooke City hyperspectral iamge
fname = 'C:\\spectral_data\\spectral_images\\AVIRIS_Cuprite\\AVIRIS_cuprite_ang20200712t201415_subset'
fname_hdr = 'C:\\spectral_data\\spectral_images\\AVIRIS_Cuprite\\AVIRIS_cuprite_ang20200712t201415_subset.hdr'

# Open the image and read into an array
im = spectral.envi.open(fname_hdr, fname)
wl_im = np.asarray(im.bands.centers)
# Load the image into memory
im.Arr = im.load()
imArr = im.Arr
print(f'Shape of ImArr = {imArr.shape}')
imList = np.reshape(imArr, (im.nrows*im.ncols, im.nbands))
print(f'Shape of imList = {imList.shape}')
# Out:
# Shape of ImArr = (2000, 550, 372)
# Shape of imList = (1100000, 372)

# %%
# display the image
sm2.display_RGB(imArr, wl_im, rotate=True)
plt.title('RGB Image');

# %%
# explore the image in our hyperspectral image viewer
from hsiViewer import hsi_viewer as hv
#hv.viewer(im)

# %% [markdown]
# # Download the Spectral Library for Unmixing

# %%
# To download and use the Cooke City spectral library image:
hsi_data.download('USGS_splib07b')
fname = hsi_data.get_fname('USGS_splib07b')
# Out:
# Available Files:
# C:\spectral_data\spectral_libraries\USGS_splib07b\splib07b_asdfr.hdr
# C:\spectral_data\spectral_libraries\USGS_splib07b\splib07b_asdfr.sli
# C:\spectral_data\spectral_libraries\USGS_splib07b\splib07b_asdhr.hdr
# C:\spectral_data\spectral_libraries\USGS_splib07b\splib07b_asdhr.sli
# C:\spectral_data\spectral_libraries\USGS_splib07b\splib07b_asdng.hdr
# C:\spectral_data\spectral_libraries\USGS_splib07b\splib07b_asdng.sli
# Primary Image Filename:
# C:/spectral_data\spectral_libraries\USGS_splib07b/splib07b_asdfr.sli

# %%
fname = 'C:/spectral_data/spectral_libraries/USGS_splib07b/splib07b_asdfr.sli'
fname_hdr = 'C:/spectral_data/spectral_libraries/USGS_splib07b/splib07b_asdfr.hdr'

# Open the image and read into an array
lib = spectral.envi.open(fname_hdr, fname)
wl = np.asarray(im.bands.centers)
# Load the image into memory
names = lib.names
spectra = lib.spectra
wl_lib = np.asarray(lib.bands.centers)

# %%
names
# Out:
# ['Alizarin_crimson (dk) GDS780',
#  'Aluminum brushed 293K',
#  'Asphalt GDS376 Blck_Road old',
#  'Asphalt_Shingle GDS366 Tan',
#  'Asphalt_Shingle GDS367 DkGry',
#  'Asphalt_Shingle GDS368 Lgray',
#  'Asphalt_Tar GDS346 Blck_Roof',
#  'Bone_black GDS808',
#  'Brick GDS347 Paving Tan',
#  'Brick GDS348 Pave DkBrwngrey',
#  'Brick GDS349 Paving Red',
#  'Brick GDS350 Dk Red Building',
#  'Brick GDS353 Building MedRed',
#  'Brick GDS354 Building Lt Gry',
#  'Brick GDS355 Paving Dk Gry',
#  'Brilliant(Hansa)yellowGDS785',
#  'Burlap_Fabric GDS430 Brown',
#  'Burnt_umber GDS811',
#  'Cadmium_orange_0 GDS786',
#  'Cadmium_orange_1 (dk) GDS781',
#  'Cadmium_red_2 GDS778',
#  'Cadmium_yellow_6 med GDS788',
#  'Cardboard GDS371 Brn Corgted',
#  'Cedar_Shake GDS357 Fresh',
#  'Cedar_Shake GDS358 SlgWeathr',
#  'Cedar_Shake GDS359 MedWeathr',
#  'Cedar_Shake GDS360 H Weamoss',
#  'Cedar_Shake GDS361 HiWeather',
#  'Cerium_Oxide 5-9s SPEX 11781',
#  'Cerulean_blue GDS797',
#  'Cinder_Block GDS356 Lg Grey',
#  'Coated_Steel_Girder WTC01-8',
#  'Cobalt_blue GDS790',
#  'Cobalt_green GDS816',
#  'Cobalt_violet GDS803',
#  'Concrete GDS375 Lt Gry Road',
#  'Concrete WTC01-37A',
#  'Cotton_Fabric GDS437 White',
#  'Dysprosium_Oxide JMC315',
#  'Erbium_Oxide J.M. 317',
#  'Europium_Oxide A-4 SPEX',
#  'Europium_Oxide GDS33C',
#  'Fiberglass GDS335 Wh Roofing',
#  'Fiberglass GDS336 Grn Roofng',
#  'Fiberglass GDS337 Grn Roofng',
#  'Fiberglass GDS374 Pnk Insul',
#  'Fiberglass GDS399 Clear Roof',
#  'Gadolinium_Nitrate_Hydrate',
#  'Gadolinium_Oxide A-5 SPEX',
#  'Gadolinium_Oxide JMC313',
#  'GalvanizedSheetMetal GDS334',
#  'Holmium_Oxide 11281',
#  'IronPowder SA-209309 325mesh',
#  'Iron oxide_#4820 GDS782',
#  'Iron_oxide GDS810 (Mars) blk',
#  'Italian_burnt_sienna GDS812',
#  'Italian_nat_sienna GDS805',
#  'Lanthanum_Oxide 1271 SPEX',
#  'Lazurite GDS792 RussianPrem',
#  'Lead-tin_yellow GDS793',
#  'Lead_White GDS796',
#  'Lutetium_Oxide LU60-2 SPEX',
#  'Malachite GDS801 synthetic',
#  'Manganese_violet GDS804',
#  'Naples_yellow GDS787',
#  'Nat.Madder_Lake_Albas GDS784',
#  'Natural_umber GDS809 (raw)',
#  'Neodymium_Oxide GDS34B',
#  'Neodymium_Oxide ND64-1 SPEX',
#  'Nickel_Powder SA-268283 <1um',
#  'Nickel_Powder SA-577995 nano',
#  'Nylon_Carpet GDS535 LtBrown',
#  'Nylon_Carpet GDS536 Gry Pile',
#  'Nylon_Fabric GDS431 Red RpSt',
#  'Nylon_Fabric GDS432 Grn RpSt',
#  'Nylon_Fabric GDS433 Blu RpSt',
#  'Nylon_Fabric GDS436 BlkCoatd',
#  'Nylon_Webbing GDS428 OlvDrab',
#  'Nylon_Webbing GDS438 Flr Yel',
#  'OiledMarshPlant DWO-2-BAT-08',
#  'OiledMarshPlant DWO-2-BAT-09',
#  'OiledMarshPlant DWO-2-DEL-04',
#  'Oiled_marsh_dry DWO-3-BAT-09',
#  'Oiled_marsh DWO-3-BAT-06',
#  'Oiled_marsh DWO-3-BAT-09',
#  'Oiled_P.austral. DWO-3-DEL-1',
#  'Oiled_S.altern. DWO-3-BAT-06',
#  'Oiled_sand_area     GrndIsle',
#  'Oiled_sand_brown    GrndIsle',
#  'Oiled_sand_dark     GrndIsle',
#  'Oil_BlackPoolonBeach DWO-06b',
#  'Oil_waterEmuls. DWO-3-BAT-09',
#  'Oxide_of_chromium GDS795',
#  'Painted_Aluminum GDS333 LgGr',
#  'Paper_Cotton_Bond PAPR1 100%',
#  'Particle_Board GDS364 Fn Gr',
#  'PhosphoricAcid SA-466123 80K',
#  'Phthalocyaninie_blue GDS799',
#  'Plastic_ABS GDS341 BlackPipe',
#  'Plastic_HDPE GDS351 BlkSheet',
#  'Plastic_HDPE GDS373 Grey Bag',
#  'Plastic_HDPE GDS384 Wht Opaq',
#  'Plastic_HDPE GDS385 WhTransl',
#  'Plastic_HDPE GDS386 Yelopaqu',
#  'Plastic_HDPE GDS387 WhTransl',
#  'Plastic_HDPE GDS389 WhTransl',
#  'Plastic_HDPE GDS390 Transpar',
#  'Plastic_HDPE GDS391 Blu-Grn',
#  'Plastic_HDPE GDS392 WhTransl',
#  'Plastic_HDPE GDS393 GlosWhTr',
#  'Plastic_HDPE GDS394 LgryTrns',
#  'Plastic_HDPE GDS400 WhTrnslu',
#  'Plastic_LDPE GDS401 Clr film',
#  'Plastic_LDPE GDS402 Clr film',
#  'Plastic_LDPE GDS404 WhTrnslu',
#  'Plastic_LDPE GDS405 Black',
#  'Plastic_LDPE GDS406 WhTrnslu',
#  'Plastic_PETE GDS379 TrnslBrn',
#  'Plastic_PETE GDS380 Clear',
#  'Plastic_PETE GDS381 Clr-prpl',
#  'Plastic_PETE GDS382 Black',
#  'Plastic_PETE GDS383 Clrbluis',
#  'Plastic_Pipe GDS342 Black',
#  'Plastic_Pipe GDS344 Blue',
#  'Plastic_PVC GDS338 White',
#  'Plastic_Tarp GDS339 Green',
#  'Plastic_Tarp GDS340 Blu_Wovn',
#  'Plastic_Tyvek GDS369 White',
#  'Plastic_Vinyl GDS372 White',
#  'Plastic_Vinyl GDS395 Clr1mm',
#  'Plastic_Vinyl GDS396 Clr1mm',
#  'Plastic_Vinyl GDS397 Cl0.4mm',
#  'Plastic_Vinyl GDS398 Red Toy',
#  'Plastic_Visqueen GDS370 Clr',
#  'Plywood GDS365 Fresh Pine',
#  'Polyester_Pile GDS434 Blk',
#  'Polyester_Pile GDS435 DkGrn',
#  'Polyester_Webbing GDS429 Blk',
#  'Polystyrene GDS345 BluInsul',
#  'Praseodymium_Chloride_39386',
#  'Praseodymium_Nitrate_Hexahyd',
#  'Praseodymium_Oxide GDS35',
#  'Praseodymium_Oxide PR62 SPEX',
#  'Prussian_blue GDS802',
#  'Roofing_Felt GDS377 Black',
#  'Rusted_Tin_Can GDS378 MV99-6',
#  'Samarium_Oxide B-5 SPEX',
#  'Samarium_Oxide GDS36',
#  'Scandium_Oxide J.M. 300 S575',
#  'Sheet_Metal GDS352 crg Galvn',
#  'Spectralon99WhiteRef LSPHERE',
#  'Strand_Board GDS362 Oriented',
#  'Tar_Paper GDS285A New Blk',
#  'Tar_Paper GDS285B Weath Blk',
#  'Terbium_(III)_Chloride 35798',
#  'Terbium_Oxide 10917 G17T013',
#  'Terra_Pozzuoli GDS806',
#  'Terrycloth_Fabric GDS537 Yel',
#  'Thulium_Oxide J.M. 318 S4939',
#  'Titanium_dioxide GDS798 TiO2',
#  'Ultramarine GDS791 sy vdark',
#  'Venetian_red GDS783',
#  'Verdigris GDS789',
#  'Vermiculite+0wt%amph. GDS327',
#  'Vermiculite+1wt%amph. GDS451',
#  'Vermiculite+5wt%amph. GDS454',
#  'Vermiculite ALB006CH01 exOre',
#  'Vermiculite ALB22SC00 expOre',
#  'Vermiculite ALB23SC00 expOre',
#  'Vermiculite at1UI expand Ore',
#  'Vermiculite GDS327 expandOre',
#  'Vermiculite GDS332 expandOre',
#  'Vermiculite GDS445 expandOre',
#  'Vermiculite GDS450 expandOre',
#  'Vermiculite GDS453 expandOre',
#  'Vermiculite GDS455 expandOre',
#  'Vermiculite GDS460 expandOre',
#  'Vermiculite GDS626 expandOre',
#  'Vermiculite GDS627 expandOre',
#  'Vermiculite GDS628 expandOre',
#  'Vermiculite GDS629 expandOre',
#  'Vermiculite GDS631 expandOre',
#  'Vermiculite GDS649 expandOre',
#  'Vermiculite GDS650 expandOre',
#  'Vermiculite GDS651 expandOre',
#  'Vermiculite GDS652 expandOre',
#  'Vermiculite GDS653 expandOre',
#  'Vermiculite GDS663 expandOre',
#  'Vermiculite GDS700 expandOre',
#  'Vermiculite GDS701 expandOre',
#  'Vermiculite GDS823 expandOre',
#  'Vermiculite GDS836 expandOre',
#  'Vermiculite GDS847 expandOre',
#  'Vermiculite GDS850 expandOre',
#  'Vermiculite GDS876 expandOre',
#  'Vermiculite GDS886 expandOre',
#  'Vermiculite GDS887 expandOre',
#  'Vermiculite GDS906 expandOre',
#  'Vermiculite GDS907 expandOre',
#  'Vermiculite GDS908 expandOre',
#  'Vermiculite GDS909 expandOre',
#  'Vermiculite GDS910 expandOre',
#  'Vermiculite GDS911 expandOre',
#  'Vermiculite GDS912 expandOre',
#  'Vermiculite GDS913 expandOre',
#  'Vermiculite GDS914 expandOre',
#  'Vermiculite GDS915 expandOre',
#  'Vermiculite GDS916 expandOre',
#  'Vermiculite GDS917 expandOre',
#  'Vermiculite GDS918 expandOre',
#  'Vermiculite GDS919 expandOre',
#  'Vermiculite GDS920 expandOre',
#  'Vermiculite GDS921 expandOre',
#  'Vermiculite GDS922 expandOre',
#  'Vermiculite GDS923 expandOre',
#  'Vermiculite GDS924 expandOre',
#  'Vermiculite GDS925 expandOre',
#  'Vermiculite Li2UI expand Ore',
#  'Vermillion_GDS779',
#  'Viridian GDS800',
#  'Wood_Beam GDS363 Nw Pine 2X4',
#  'WTC_Dust_Debris WTC01-28',
#  'WTC_Dust_Debris WTC01-2',
#  'Yellow_ochre GDS794 Germany',
#  'Ytterbium_Oxide J.M. 319',
#  'Yttrium_Oxide 5-9s SPEX',
#  'Yttrium_Oxide J.M. 301',
#  'Zinc_oxide GDS807 (ZnO)',
#  'Melting_snow mSnw01a+0.5_veg',
#  'Melting_snow mSnw01a',
#  'Melting_snow mSnw03+0.5_veg',
#  'Melting_snow mSnw03',
#  'Melting_snow mSnw04',
#  'Melting_snow mSnw05',
#  'Melting_snow mSnw08+0.5_veg',
#  'Melting_snow mSnw08',
#  'Melting_snow mSnw09+0.5_veg',
#  'Melting_snow mSnw09 (slush)',
#  'Melting_snow mSnw12 (slush)',
#  'Melting_snow mSnw14 (slush)',
#  'Melting_snow mSnw15 (slush)',
#  'Melting_snow mSnw16+0.25_veg',
#  'Melting_snow mSnw16+0.5_veg',
#  'Melting_snow mSnw16 (slush)',
#  'Red_Coated_Algea_Water RCAW1',
#  'Water+Montmor SWy-2+0.50g/l',
#  'Water+Montmor SWy-2+1.67g/l',
#  'Water+Montmor SWy-2+16.5g/l',
#  'Water+Montmor SWy-2+5.01g/l',
#  'Actinolite HS116.1B',
#  'Actinolite HS116.2B',
#  'Actinolite HS116.3B',
#  'Actinolite HS116.4B',
#  'Actinolite HS22.1B',
#  'Actinolite HS22.2B',
#  'Actinolite HS22.3B',
#  'Actinolite HS22.4B',
#  'Actinolite HS315.1B',
#  'Actinolite HS315.2B',
#  'Actinolite HS315.4B',
#  'Albite HS143.1B Plagioclase',
#  'Albite HS143.2B Plagioclase',
#  'Albite HS143.3B Plagioclase',
#  'Albite HS143.4B Plagioclase',
#  'Albite HS143.6  Plagioclase',
#  'Albite HS324.1B Plagioclase',
#  'Albite HS324.2B Plagioclase',
#  'Albite HS324.3B Plagioclase',
#  'Albite HS324.4B Plagioclase',
#  'Albite HS66.1B Plagioclase',
#  'Albite HS66.2B Plagioclase',
#  'Albite HS66.4B Plagioclase',
#  'Albite HS66.6  Plagioclase',
#  'Allanite HS293.1B',
#  'Allanite HS293.2B',
#  'Allanite HS293.3B',
#  'Allanite HS293.4B',
#  'Allanite HS293.6',
#  'Allanite_REE crystal WS532',
#  'Almandine HS114.1B Garnet',
#  'Almandine HS114.2B Garnet',
#  'Almandine HS114.3B Garnet',
#  'Almandine HS114.4B Garnet',
#  'Almandine HS114.6  Garnet',
#  'Alunite HS295.1B',
#  'Alunite HS295.3B',
#  'Alunite HS295.4B',
#  'Alunite HS295.6',
#  'Alunite HS295',
#  'Ancylite_REE WS321 Darby MT',
#  'Andesine HS142.1B',
#  'Andesine HS142.2B',
#  'Andesine HS142.3B',
#  'Andesine HS142.4B',
#  'Andradite HS111.1B Garnet',
#  'Andradite HS111.2B Garnet',
#  'Andradite HS111.3B Garnet',
#  'Andradite HS111.4B Garnet',
#  'Andradite HS111.6  Garnet',
#  'Anorthite HS349.1B Plagio',
#  'Anorthite HS349.2B Plagio',
#  'Anorthite HS349.3B Plagio',
#  'Anorthite HS349.4B Plagio',
#  'Anthophyllite HS286.1B',
#  'Anthophyllite HS286.2B',
#  'Anthophyllite HS286.3B',
#  'Anthophyllite HS286.4B',
#  'Arsenopyrite HS262.1B',
#  'Arsenopyrite HS262.2B',
#  'Arsenopyrite HS262.3B',
#  'Arsenopyrite HS262.4B',
#  'Axinite HS342.1B',
#  'Axinite HS342.2B',
#  'Axinite HS342.3B',
#  'Axinite HS342.4B',
#  'Axinite HS342.6',
#  'Bastnaesite_REE WS320 crystl',
#  'Beidellite GDS124',
#  'Beryl HS180.1B',
#  'Beryl HS180.2B',
#  'Beryl HS180.3B',
#  'Beryl HS180.4B',
#  'Beryl HS180.6',
#  'Bronzite HS9.1B',
#  'Bronzite HS9.2B',
#  'Bronzite HS9.3B',
#  'Bronzite HS9.4B',
#  'Brookite HS443.2B',
#  'Brookite HS443.6',
#  'Brucite HS247.1B',
#  'Brucite HS247.2B',
#  'Brucite HS247.3B',
#  'Brucite HS247.4B',
#  'Bytownite HS105.1B Plagio',
#  'Bytownite HS105.2B Plagio',
#  'Bytownite HS105.3B Plagio',
#  'Bytownite HS105.4B Plagio',
#  'Bytownite HS105.6  Plagio',
#  'Calcite GDS304 75-150um',
#  'Calcite_REE-bearing WS319a',
#  'Carbon_Black GDS68',
#  'Carnallite HS430.1B',
#  'Carnallite HS430.2B',
#  'Carnallite HS430.3B',
#  'Carnallite HS430.4B',
#  'Carnallite HS430.6',
#  'Cassiterite HS279.1B',
#  'Cassiterite HS279.2B',
#  'Cassiterite HS279.3B',
#  'Cassiterite HS279.4B',
#  'Celestite HS251.1B Barite',
#  'Celestite HS251.2B Barite',
#  'Celestite HS251.3B Barite',
#  'Celestite HS251.4B Barite',
#  'Chalcopyrite HS431.1B',
#  'Chalcopyrite HS431.2B',
#  'Chalcopyrite HS431.3B',
#  'Chalcopyrite HS431.4B',
#  'Chlorapatite_REE WS422 xtl',
#  'Chlorapatite WS423',
#  'Chlorite HS179.1B',
#  'Chlorite HS179.2B',
#  'Chlorite HS179.3B',
#  'Chlorite HS179.4B',
#  'Chlorite HS179.6',
#  'Chromite HS281.1B',
#  'Chromite HS281.2B',
#  'Chromite HS281.3B',
#  'Chromite HS281.4B',
#  'Chrysocolla HS297.1B',
#  'Chrysocolla HS297.2B',
#  'Chrysocolla HS297.3B',
#  'Chrysocolla HS297.4B',
#  'Chrysotile ML99-12A Coar Fib',
#  'Chrysotile ML99-12C Fine Fib',
#  'Clinochlore_Fe GDS157.b',
#  'Corundum HS283.1B',
#  'Corundum HS283.2B',
#  'Corundum HS283.4B',
#  'Cummingtonite HS294.1B',
#  'Cummingtonite HS294.2B',
#  'Cummingtonite HS294.3B',
#  'Cummingtonite HS294.4B',
#  'Cummingtonite HS294.6',
#  'Cuprite HS127.2B',
#  'Cuprite HS127.3B',
#  'Cuprite HS127.4B',
#  'Datolite HS442.1B',
#  'Datolite HS442.2B',
#  'Datolite HS442.4B',
#  'Diaspore HS416.1B',
#  'Diaspore HS416.2B',
#  'Diaspore HS416.3B',
#  'Diaspore HS416.4B',
#  'Diaspore HS416.6',
#  'Diopside HS15.1B pyroxene',
#  'Diopside HS15.2B pyroxene',
#  'Diopside HS15.3B pyroxene',
#  'Diopside HS15.4B pyroxene',
#  'Diopside HS15.8  pyroxene',
#  'Diopside HS317.1B (Cr)Pyx',
#  'Diopside HS317.2B (Cr)Pyx',
#  'Diopside HS317.3B (Cr)Pyx',
#  'Diopside HS317.4B (Cr)Pyx',
#  'Diopside HS317.6  (Cr)Pyx',
#  'Dolomite ML97-3 Ferroan',
#  'Epidote GDS301 75-150um',
#  'Fluorapatite_REE WS418 xtl',
#  'Fluorapatite_REE WS420 xtl',
#  'Fluorapatite WS416 xtl',
#  'Forsterite_REE AZ-01 ASU',
#  'Galena HS37.3fg',
#  'Galena HS37.3',
#  'Gibbsite HS423.1B',
#  'Gibbsite HS423.2B',
#  'Gibbsite HS423.3B',
#  'Gibbsite HS423.4B',
#  'Gibbsite HS423.6',
#  'Glauconite HS313.1B',
#  'Glauconite HS313.3B',
#  'Glauconite HS313.4B',
#  'Glauconite HS313.6',
#  'Glaucophane HS426.1B',
#  'Glaucophane HS426.2B',
#  'Glaucophane HS426.3B',
#  'Glaucophane HS426.4B',
#  'Glaucophane HS426.6',
#  'Goethite GDS134',
#  'Gypsum HS333.1B (Selenite)',
#  'Gypsum HS333.2B (Selenite)',
#  'Gypsum HS333.3B (Selenite)',
#  'Gypsum HS333.4B (Selenite)',
#  'Halite HS433.1B',
#  'Halite HS433.2B',
#  'Halite HS433.3B',
#  'Halite HS433.4B',
#  'Halite HS433.6',
#  'Hedenbergite HS10.1B',
#  'Hedenbergite HS10.2B',
#  'Hedenbergite HS10.3B',
#  'Hedenbergite HS10.4B',
#  'Hematite HS45.3',
#  'Hornblende HS16.2B',
#  'Hornblende HS16.3B',
#  'Hornblende HS16.4B',
#  'Hornblende HS16.6',
#  'Hornblende HS177.1B',
#  'Hornblende HS177.3B',
#  'Hornblende HS177.4B',
#  'Hornblende HS177.6',
#  'Ilmenite HS231.2B',
#  'Ilmenite HS231.3B',
#  'Ilmenite HS231.4B',
#  'Jadeite HS343.1B',
#  'Jadeite HS343.2B',
#  'Jadeite HS343.3B',
#  'Jadeite HS343.4B',
#  'Jadeite HS343.6',
#  'Kieserite KIEDE1.a crse gr',
#  'Kieserite KIEDE1.b fine gr',
#  'Knebelite HS419.1B',
#  'Knebelite HS419.2B',
#  'Knebelite HS419.3B',
#  'Knebelite HS419.4B',
#  'Knebelite HS419.6',
#  'Labradorite HS17.1B',
#  'Labradorite HS17.2B',
#  'Labradorite HS17.3B',
#  'Labradorite HS17.4B',
#  'Lazurite HS418.1B',
#  'Lazurite HS418.2B',
#  'Lazurite HS418.3B',
#  'Lazurite HS418.4B',
#  'Lepidolite HS167.1B',
#  'Lepidolite HS167.2B',
#  'Lepidolite HS167.3B',
#  'Lepidolite HS167.4B',
#  'Lepidolite HS167.6',
#  'Magnetite HS195.1B',
#  'Magnetite HS195.2B',
#  'Magnetite HS195.3B',
#  'Magnetite HS195.4B',
#  'Magnetite HS78.1B',
#  'Magnetite HS78.2B',
#  'Magnetite HS78.3B',
#  'Magnetite HS78.4B',
#  'Malachite HS254.1B',
#  'Malachite HS254.2B',
#  'Malachite HS254.3B',
#  'Malachite HS254.4B',
#  'Microcline HS103.1B Feldspar',
#  'Microcline HS103.2B Feldspar',
#  'Microcline HS103.3B Feldspar',
#  'Microcline HS103.4B Feldspar',
#  'Microcline HS103.6  Feldspar',
#  'Microcline HS151.1B Feldspar',
#  'Microcline HS151.2B Feldspar',
#  'Microcline HS151.3B Feldspar',
#  'Microcline HS151.4B Feldspar',
#  'Microcline HS151.6  Feldspar',
#  'Monazite HS255.1B',
#  'Monazite HS255.2B',
#  'Monazite HS255.3B',
#  'Monazite HS255.4B',
#  'Monazite_REE GDS947 Calif',
#  'Monazite_REE GDS955 Iveland',
#  'Monazite_REE GDS957 New Mex',
#  'Monazite_REE WS385 crystal',
#  'Monticellite HS339.1B',
#  'Monticellite HS339.2B',
#  'Monticellite HS339.3B',
#  'Monticellite HS339.4B',
#  'Muscovite HS146.1B',
#  'Muscovite HS146.3B',
#  'Muscovite HS146.4B',
#  'Natrolite HS169.1B Zeolite',
#  'Natrolite HS169.2B Zeolite',
#  'Natrolite HS169.3B Zeolite',
#  'Natrolite HS169.4B Zeolite',
#  'Nepheline HS19.1B',
#  'Nephrite HS296.1B',
#  'Nephrite HS296.3B',
#  'Nephrite HS296.4B',
#  'Olivine HS285.2B Fo80',
#  'Olivine HS285.4B Fo80',
#  'Olivine HS420.1B',
#  'Olivine HS420.2B',
#  'Olivine HS420.3B',
#  'Olivine HS420.4B',
#  'Parisite_REE WS319 crystal',
#  'Perthite HS415.1B',
#  'Perthite HS415.2B',
#  'Perthite HS415.3B',
#  'Perthite HS415.4B',
#  'Perthite HS415.6',
#  'Phlogopite HS23.1B',
#  'Phlogopite HS23.2B',
#  'Phlogopite HS23.3B',
#  'Phlogopite HS23.4B',
#  'Pigeonite HS199.1B',
#  'Pigeonite HS199.2B',
#  'Pigeonite HS199.3B',
#  'Pigeonite HS199.4B',
#  'Portlandite GDS525 Ca(OH)2',
#  'Prehnite GDS613.a <60um',
#  'Prehnite GDS613.b >60um',
#  'Psilomelane HS139.1B',
#  'Psilomelane HS139.2B',
#  'Psilomelane HS139.3B',
#  'Psilomelane HS139.4B',
#  'Pyrite GDS483.c 30-60um',
#  'Pyrolusite HS138.3B',
#  'Pyromorphite_REE WS427 xtl',
#  'Pyroxene HS119.1B',
#  'Pyroxene HS119.2B',
#  'Pyroxene HS119.3B',
#  'Pyroxene HS119.4B',
#  'Pyrrhotite HS269.1B',
#  'Pyrrhotite HS269.2B',
#  'Pyrrhotite HS269.3B',
#  'Pyrrhotite HS269.4B',
#  'Quartz HS32.1B',
#  'Quartz HS32.2B',
#  'Quartz HS32.3B',
#  'Rhodochrosite HS338.6',
#  'Richterite HS336.1B Amphibol',
#  'Richterite HS336.2B Amphibol',
#  'Richterite HS336.3B Amphibol',
#  'Richterite HS336.4B Amphibol',
#  'Richterite HS336.6  Amphibol',
#  'Serpentine HS318.1B',
#  'Serpentine HS318.2B',
#  'Serpentine HS318.3B',
#  'Serpentine HS318.4B',
#  'Serpentine HS318.6',
#  'Serpentine HS8.1B',
#  'Serpentine HS8.2B',
#  'Serpentine HS8.3B',
#  'Serpentine HS8.4B',
#  'Serpentine HS8.6',
#  'Siderite HS271.1B',
#  'Siderite HS271.2B',
#  'Siderite HS271.3B',
#  'Siderite HS271.4B',
#  'Smaragdite HS290.1B Amphibol',
#  'Smaragdite HS290.2B Amphibol',
#  'Smaragdite HS290.3B Amphibol',
#  'Smaragdite HS290.4B Amphibol',
#  'Smaragdite HS290.6  Amphibol',
#  'Sphalerite HS136.6',
#  'Spodumene HS210.1B',
#  'Spodumene HS210.2B',
#  'Spodumene HS210.3B',
#  'Spodumene HS210.4B',
#  'Staurolite HS188.1B',
#  'Staurolite HS188.2B',
#  'Staurolite HS188.3B',
#  'Staurolite HS188.4B',
#  'Stilbite HS482.1B Zeolite',
#  'Stilbite HS482.2B Zeolite',
#  'Stilbite HS482.3B Zeolite',
#  'Stilbite HS482.4B Zeolite',
#  'Stilbite HS482.6  Zeolite',
#  'Strontianite HS272.1B',
#  'Strontianite HS272.2B',
#  'Strontianite HS272.3B',
#  'Strontianite HS272.4B',
#  'Talc HS21.1B',
#  'Talc HS21.2B',
#  'Talc HS21.3B',
#  'Talc HS21.4B',
#  'Thenardite HS450.1B',
#  'Thenardite HS450.2B',
#  'Thenardite HS450.3B',
#  'Thenardite HS450.4B',
#  'Topaz HS184.1B',
#  'Topaz HS184.2B',
#  'Topaz HS184.3B',
#  'Topaz HS184.4B',
#  'Tremolite HS18.1B',
#  'Tremolite HS18.2B',
#  'Tremolite HS18.3B',
#  'Tremolite HS18.4B',
#  'Ulexite HS441.1B',
#  'Ulexite HS441.2B',
#  'Ulexite HS441.3B',
#  'Ulexite HS441.4B',
#  'Uralite HS345.1B',
#  'Uralite HS345.2B',
#  'Uralite HS345.3B',
#  'Uralite HS345.4B',
#  'Uralite HS345.6',
#  'Vesuvianite HS446.1B Idocras',
#  'Vesuvianite HS446.2B Idocras',
#  'Vesuvianite HS446.3B Idocras',
#  'Vesuvianite HS446.4B Idocras',
#  'Vesuvianite HS446.6  Idocras',
#  'Witherite HS273.1B',
#  'Witherite HS273.2B',
#  'Witherite HS273.3B',
#  'Witherite HS273.4B',
#  'Wollastonite HS348.1B',
#  'Wollastonite HS348.2B',
#  'Wollastonite HS348.3B',
#  'Wollastonite HS348.4B',
#  'Xenotime GDS966 Iveland REE',
#  'Zoisite HS347.1B',
#  'Zoisite HS347.2B',
#  'Zoisite HS347.3B',
#  'Zoisite HS347.4B',
#  'Zoisite HS347.6',
#  'Acetylene MTG 80K',
#  'Benzene JTB-9155 T~84K',
#  'Butane Camco frost 83K',
#  'Decane SA-30550 T~76K',
#  'Ethane MTG T~76K',
#  'Ethylene MTG ice block 80K',
#  'Heptane SA-H2198 MedFrost85K',
#  'Hexane SA-139386 CrsFrost85K',
#  'Methane XCEL liquid T~77K',
#  'Naphthalene ENOZ cgr 89K',
#  'Nonane fine frost 84K',
#  'Octane SA-74822 medfrost 85K',
#  'Paraffin gfwax T~85K',
#  'Pentane SA-76878 fine gr 85K',
#  'Peptidogylcan SA-69554',
#  'Propane SA-536172 78K ground',
#  'Propene SA-295663 ice 77K',
#  'Propyne SA-295493 Frost 80K',
#  'Toluene SA-244511 frost 84K',
#  'Xylene(s) ice 77K',
#  'Acid_Mine_Dr Assemb1-Fe3+',
#  'Acid_Mine_Dr Assemb2-Fe3+',
#  'Alunite+Dickite MV99-6-26b',
#  'Alunite-K CU91-217G1 HiTemp',
#  'Alunite0.35K+.65Na CU91-217H',
#  'Alunite_K-Na CU91-217H1 LowT',
#  'Alunite_K CU98-5C MedTemp',
#  'Alunite_NH4+Jaro NMNH145596A',
#  'Alun_Na+Kaol+Hemat  MV00-11a',
#  'Beidellite+Montmor GDS123',
#  'BurnArea_TopSurface WRF00-02',
#  'BurnArea_Traverse WRF00-01',
#  'Calcite+Talc PC99-1G',
#  'Calcite.33+Epidote.67 GDS311',
#  'Calcite.67+Epidote.33 GDS310',
#  'Chabazite+Thom+Wair HS193.3B',
#  'Chl.33+Epid.33+Cal.33 GDS319',
#  'Chlor.2+Epid.2+Calc.6 GDS314',
#  'Chlor.2+Epid.6+Calc.2 GDS312',
#  'Chlor.6+Epid.2+Calc.2 GDS313',
#  'Chlorit.33+Calcite.67 GDS315',
#  'Chlorite.33+Epidot.67 GDS318',
#  'Chlorite.67+Calcit.33 GDS316',
#  'Chlorite.67+Epidot.33 GDS317',
#  'ClinozoisiteEpidote HS299.1B',
#  'ClinozoisiteEpidote HS299.2B',
#  'ClinozoisiteEpidote HS299.4B',
#  'ClinozoisiteEpidote HS299.6',
#  'Cordierite-QtzMus HS346.1B',
#  'Cordierite-QtzMus HS346.2B',
#  'Cordierite-QtzMus HS346.3B',
#  'Cordierite-QtzMus HS346.4B',
#  'Covellite-Pyrite HS477.4B',
#  'Covellite-Pyrite HS477.6',
#  'Dolomit+Calcite+Talc PC99-1E',
#  'Goethite_Phyllite CU91-236A',
#  'Gyp+jar+ill BRCM1 Marysvale',
#  'Halloysite CU91-242D',
#  'Hematitic_Alt._Tuff CU91-223',
#  'Hydrated_Volc_Tuff CU01-4A',
#  'Illite CU00-5B Hi-Al+Quartz',
#  'Kalun+kaol+gth mv2-ar3',
#  'Kaol_wxl+others CU00-19A',
#  'Kaol_wxl+others CU91-200A',
#  'Limestone CU02-11A',
#  'Magnesite+Hydromag HS47.1B',
#  'Magnesite+Hydromag HS47.2B',
#  'Magnesite+Hydromag HS47.3B',
#  'Magnesite+Hydromag HS47.4B',
#  'Muscovite+Pyrophyl JH_PYRP1',
#  'Muscovite-low-Al CU98-8H',
#  'Muscovite-medhi-Al CU91-252D',
#  'Muscovite-medlowAl CU91-250A',
#  'Natrolite+Zeolite HS168.1B',
#  'Natrolite+Zeolite HS168.2B',
#  'Natrolite+Zeolite HS168.3B',
#  'Natrolite+Zeolite HS168.4B',
#  'Nontronite+others CU00-13A',
#  'Opalized Tuff CU00-15E',
#  'Pyrophyl+Muscovite JH_PYRM1',
#  'Pyroxene_Basalt CU01-20A',
#  'Sand DWO-3-DEL2ar1    no oil',
#  'Sand DWO-3-DEL2ar2 wet noOil',
#  'Sand DWO-3-DEL2a  no vis.oil',
#  'Sand DWO-3-DEL2b wet  no oil',
#  'Sand DWO-3-DEL2c  no vis.oil',
#  'Sand DWO-3-DEL2d wet  no oil',
#  'Sand GrndIsle1        no oil',
#  'Sand GrndIsle2 no visibl oil',
#  'Stonewall_Playa_Dry_Mud 2001',
#  'Talc+Clinochlore HS327.3B',
#  'White_Crust LV30 starkeyite',
#  'Xenotime+Monazite_REE WS384',
#  'Zincite+Franklin HS147.1B',
#  'Zincite+Franklin HS147.2B',
#  'Zincite+Franklin HS147.3B',
#  'Zincite+Franklin HS147.4B',
#  'Antigorite+.2DryGrass  AMX26',
#  'Antigorite+.33DryGrass AMX25',
#  'Aspen Aspen-1 green-top',
#  'Aspen Aspen-2 green-bottom',
#  'Aspen Aspen-3 yellowGreenTop',
#  'Aspen Aspen-4 yellow-top',
#  'Buckbrush CA01-CECU-1 bush 1',
#  'Buckbrush CA01-CECU-2 bush 2',
#  'Buckbrush CA01-CECU-3 bush 3',
#  'Cactus Opuntia-1 purple_pad',
#  'Chamise CA01-ADFA-1 bush 1',
#  'Chamise CA01-ADFA-2 bush 2',
#  'Cheatgrass ANPC1 field calib',
#  'D.spicata DWV6-0511 dryNPV.a',
#  'Engelmann-Spruce ES-Needls-1',
#  'Flower Geranium-1 Red-Orange',
#  'Flower Pansy-1 Yellow',
#  'Flower Petunia-1 Pink',
#  'Flower Petunia-2 Purple',
#  'Flower Petunia-3 White',
#  'Flower Platycodon-1 Purple',
#  'Flower Platycodon-2 White',
#  'Grass_AETR70 CA01-AETR-2 NPV',
#  'Grass_AETR95 CA01-AETR-1 NPV',
#  'Grass CA01-TACA-1 meadow NPV',
#  'Grass_Golden_Dry GDS480',
#  'Gray-Pine CA01-PISA-1 branch',
#  'Gray-Pine CA01-PISA-2 branch',
#  'Gray-Pine CA01-PISA-3 needls',
#  'Hyacinth DWO-3-DEL-2 leaf.a',
#  'J.roemer. DWV1-0511a gr.a',
#  'J.roemer. DWV1-0511b dkgrn.a',
#  'J.roemer. DWV1-0511c grbrn.a',
#  'J.roemer. DWV1-0511d NPV.a',
#  'J.roemer. DWV6a2-0511 NPV.a',
#  'LeafySpurge Spurge-A1-Jul98',
#  'LeafySpurge Spurge-A1-Jun98',
#  'LeafySpurge Spurge-A1-Oct97',
#  'LeafySpurge Spurge-A1-Sep97',
#  'LeafySpurge Spurge-A2-Jun98',
#  'LeafySpurge Spurge-B1-Jul98',
#  'LeafySpurge Spurge-B1-Oct97',
#  'LeafySpurge Spurge-B2-Jul98',
#  'LeafySpurge Spurge-B3-Jul98',
#  'LeafySpurge Spurge-C1-Oct97',
#  'Lichen Acarospora-1',
#  'Lichen Licedea-1',
#  'Lichen Licedea-2',
#  'Lichen Xanthoparmelia-1',
#  'Lichen Xanthoparmelia-2',
#  'Lichen Xanthoria-1',
#  'Lodgepole-Pine LP-Needles-1',
#  'Lodgepole-Pine LP-Needles-2',
#  'Lodgepole-Pine LP-Needles-3',
#  'Lythr.lineare CRMS326v59 grn',
#  'Manzanita CA01-ARVI-1 bush 1',
#  'Manzanita CA01-ARVI-2 bush 2',
#  'Manzanita CA01-ARVI-3 bush 3',
#  'Manzanita CA01-ARVI-4 bush 4',
#  'Manzanita CA01-ARVI-5 bush 5',
#  'Manzanita CA01-ARVI-6 bush 6',
#  'Manzanita CA01-ARVI-7 leaves',
#  'MarshWater CRMS121v69-NoGlnt',
#  'Marsh DISP60%.... CRMS326v59',
#  'Marsh DISP65%...a CRMS326v84',
#  'Marsh DISP80%...  CRMS326v64',
#  'Marsh PHAU 100%  DWO-3-DEL-2',
#  'Marsh SCAM/DISP..CRMS326v48a',
#  'Marsh SCAM/DISP..CRMS326v50a',
#  'Marsh SCAM/DISP..CRMS326v71a',
#  'Marsh SCAM42%.... CRMS326v50',
#  'Marsh SCAM45%...  CRMS121v28',
#  'Marsh SCAM50%.... CRMS326v48',
#  'Marsh SCAM50%...  CRMS121v32',
#  'Marsh SCAM60%.... CRMS326v71',
#  'Marsh SCAM66%...  CRMS121v38',
#  'Marsh SCAM71%...  CRMS121v49',
#  'Marsh SCAM72%...  CRMS121v33',
#  'Marsh SCAM77%...  CRMS121v34',
#  'Marsh SCAM81%...  CRMS121v37',
#  'Marsh sediment DWV3-0511 dry',
#  'Marsh SPAL50%...a CRMS322v52',
#  'Marsh SPAL50%...  CRMS322v52',
#  'Marsh SPAL55%...a CRMS322v25',
#  'Marsh SPAL60%...a CRMS322v55',
#  'Marsh SPAL70%...a CRMS322v16',
#  'Marsh SPAL70%...a CRMS322v79',
#  'Marsh SPAL77%...  CRMS322v83',
#  'Marsh SPAL80%...a CRMS322v06',
#  'Marsh SPAL92%...a CRMS322v78',
#  'Marsh SPAL95%...a CRMS322v68',
#  'Marsh SPPA35%...a CRMS326v81',
#  'Marsh SPPA49%...a CRMS326v06',
#  'Marsh SPPA55%...a CRMS326v02',
#  'Marsh SPPA67%...a CRMS326v10',
#  'Marsh water40%... CRMS121v69',
#  'Marsh water55%... CRMS121v47',
#  'Marsh water75%... CRMS322v84',
#  'Marsh water80%... CRMS121v23',
#  'Marsh water CRMS121v69-glint',
#  'Marsh water CRMS322v84a sunl',
#  'Marsh wrack DWV1-0511 NPV.a',
#  'Marsh wrack DWV3-0511 dryNPV',
#  'Oak Oak-Leaf-1 fresh',
#  'Oak Oak-Leaf-2 dried',
#  'Oak QUDU CA01-QUDU-1 bush 1',
#  'Oak QUDU CA01-QUDU-2 bush 2',
#  'Oak QUDU CA01-QUDU-3 bush 3',
#  'P.aus. DWO-3-DEL-2d dryNPV.a',
#  'P.austr. DWO-3-DEL-2a stems',
#  'P.austr. DWO-3-DEL-2b grn.a',
#  'P.austr. DWO-3-DEL-2c stem.a',
#  'P.australis CRMS-0153 dryNPV',
#  'Rangeland C03-004 S08% G27%',
#  'Rangeland C03-005 S25% G24%',
#  'Rangeland C03-006 S01% G39%',
#  'Rangeland C03-010 S12% G15%',
#  'Rangeland C03-013 S06% G08%',
#  'Rangeland C03-014 S26% G25%',
#  'Rangeland C03-017 S20% G19%',
#  'Rangeland C03-019 S20% G14%',
#  'Rangeland C03-021 S11% G07%',
#  'Rangeland C03-022 S12% G22%',
#  'Rangeland C03-027 S27% G19%',
#  'Rangeland C03-031 S15% G14%',
#  'Rangeland C03-032 S34% G15%',
#  'Rangeland C03-037 S37% G13%',
#  'Rangeland C03-041 S15% G06%',
#  'Rangeland C03-047 S09% G12%',
#  'Rangeland C03-050 S18% G12%',
#  'Rangeland C03-052 S22% G24%',
#  'Rangeland C03-066 S11% G17%',
#  'Rangeland C03-068 S05% G43%',
#  'Rangeland C03-070 S02% G31%',
#  'Rangeland C03-073 S30% G24%',
#  'Rangeland C03-074 S24% G16%',
#  'Rangeland C03-076 S13% G13%',
#  'Rangeland C03-077 S09% G10%',
#  'Rangeland C03-080 S18% G15%',
#  'Rangeland C03-081 S07% G23%',
#  'Rangeland C03-085 S06% G24%',
#  'Rangeland C03-086 S29% G13%',
#  'Rangeland C03-089 S20% G21%',
#  'Rangeland C03-090 S14% G31%',
#  'Rangeland C03-091 S30% G17%',
#  'Rangeland C03-095 S09% G08%',
#  'Rangeland C03-097 S07% G21%',
#  'Rangeland C04-151 S29% G05%',
#  'Rangeland C04-153 S12% G16%',
#  'Rangeland C04-154 S12% G10%',
#  'Rangeland C04-155A S03% G38%',
#  'Rangeland C04-166 S09% G10%',
#  'Rangeland C04-170 S30% G24%',
#  'Rangeland C04-175 S06% G23%',
#  'Rangeland C04-197 S17% G15%',
#  'Rangeland C04-200 S03% G17%',
#  'Rangeland C04-203 S21% G07%',
#  'Rangeland C04-204 S24% G06%',
#  'Rangeland C04-208 S15% G20%',
#  'Rangeland C04-209A S17% G04%',
#  'Rangeland C04-211 S03% G16%',
#  'Rangeland C04-214 S03% G17%',
#  'Rangeland C04-226 S05% G25%',
#  'Rangeland C04-232 S23% G13%',
#  'Rangeland C04-233 S16% G06%',
#  'Rangeland C04-236 S20% G18%',
#  'Rangeland C04-237 S05% G25%',
#  'Rangeland C04-243A S05%G02%',
#  'Rangeland C04-251 S17% G07%',
#  'Rangeland C04-252 S08% G05%',
#  'Rangeland C04-253 S27% G21%',
#  'Rangeland C04-264 S09% G18%',
#  'Rangeland C04-272 S04% G36%',
#  'Rangeland C04-273 S25% G08%',
#  'Rangeland C04-288 S19% G34%',
#  'Rangeland C04-295 S17% G17%',
#  'Rangeland L02-005 S14% G16%',
#  'Rangeland L02-013 S00% G31%',
#  'Rangeland L02-015 S01% G35%',
#  'Rangeland L02-019 S01% G06%',
#  'Rangeland L02-022 S20% G09%',
#  'Rangeland L02-023 S01% G56%',
#  'Rangeland L02-025 S00% G21%',
#  'Rangeland L02-042 S01% G57%',
#  'Rangeland L02-043 S01% G07%',
#  'Rangeland L02-045 S01% G04%',
#  'Rangeland L02-046 S16% G20%',
#  'Rangeland L02-054 S00% G21%',
#  'Rangeland L02-057 S01% G47%',
#  'Rangeland L02-058 S00% G25%',
#  'Rangeland L02-060 S00% G13%',
#  'Rangeland L02-061 S00% G06%',
#  'Rangeland L02-068A S00% G38%',
#  'Rangeland L02-069 S00% G99%',
#  'Rangeland L02-077 S00% G28%',
#  'Rangeland L04-035 S03% G54%',
#  'Rangeland L04-047 S00% G47%',
#  'Rangeland L04-058 S34% G25%',
#  'Rangeland L04-072 S30% G21%',
#  'Rangeland L04-075A S00% G49%',
#  'Rangeland L04-091 S10% G11%',
#  'Rangeland L04-095 S01% G51%',
#  'Rangeland L04-096 S00% G45%',
#  'S.altern. DWV1-0511 NPV.a',
#  'S.altern. DWV6a2-0511 stem.a',
#  'S.altern. DWV6a4-0511 gray.a',
#  'S.altern. DWV6b3-0511 NPV.a',
#  'S.alternif. CRMS322v06 grn.a',
#  'S.alterniflora CRMS322 NPV',
#  'S.america. CRMS121v38 yellow',
#  'S.americanus CRMS326v06 gr.a',
#  'Sagebrush Sage-Leaves-1 dry',
#  'Spar.patens CRMS322v06 grn.a',
#  'Toyon CA01-HEAR-1 bush',
#  'Willow_Dead FluvTailSite_A',
#  'Willow Willow-Leaves-1 dry',
#  'Yerba Santa CA01-ERCA-1 bush',
#  'Yerba Santa CA01-ERCA-2 bush']

# %% [markdown]
# ### Subset the library to only include the minerals, (spectra 249-650)

# %%
#names = names[249:650]
#spectra = spectra[249:650,:]

# %% [markdown]
# # Check Data Scale

# %%
plt.figure(figsize=(12,4))
plt.plot(wl_im, imArr[100,100,:].flatten(), label='Image Spectrum')
plt.plot(wl_im, imArr[172,233,:].flatten(), label='Very Bright Image Spectrum')
plt.plot(wl_lib, spectra[5,:].flatten(), label='Lib Spectrum')
plt.grid()
plt.legend()

# %% [markdown]
# ### Observation 1: The units on the wavelengths in the library are microns and the units on the wavelengths for the image are nanometers.  We often moodify the library to match the image as a convention, so we will multiply the wavelengths for the library by 1000 to match the image.
#
# ### Observation 2: The image and the library reflectance values are both on 0-1 scale.  This is ideal.

# %%
wl_lib = wl_lib*1000

# %%
plt.figure(figsize=(12,4))
plt.plot(wl_im, imArr[100,100,:].flatten(), label='Image Spectrum')
plt.plot(wl_im, imArr[172,233,:].flatten(), label='Very Bright Image Spectrum')
plt.plot(wl_lib, spectra[5,:].flatten(), label='Lib Spectrum')
plt.grid()
plt.legend()

# %% [markdown]
# # Check wavelengths

# %%
print(f'Number of image wavelengths: {len(wl_im)}.')
print(f'Number of library wavelengths: {len(wl_lib)}.')
print('')
print(f'First 10 image wavelengths: {wl_im[:10]}.')
print('')
print(f'First 10 library wavelengths: {wl_lib[:10]}.')
# Out:
# Number of image wavelengths: 372.
# Number of library wavelengths: 2151.
#
# First 10 image wavelengths: [381.729584 386.739563 391.749573 396.749573 401.759583 406.769562
#  411.779572 416.789581 421.799591 426.80957 ].
#
# First 10 library wavelengths: [349.99999 351.00001 352.      352.99999 354.      354.99999 356.00001
#  356.99999 358.00001 359.     ].

# %% [markdown]
# ### Observation: The library spectrum has many more wavelengths than the image.  Also, there is about 14nm between succsive image wavelength and about 1nm between library wavelengths.

# %%
plt.figure(figsize=(8,4))
plt.title('An image spectrum and a library spectrum showing band locations with markers.')
plt.plot(wl_im, imArr[100,100,:].flatten(), marker='.', label='Image Spectrum')
plt.plot(wl_lib, spectra[5,:].flatten(), marker='.', label='Orig Lib Spectrum')
plt.grid()
plt.legend()

# %% [markdown]
# ### Resampling the library wavelength to match the image.

# %%
# Create a BandResampler, which is a function that resamples spectra from one source to match a different source.
# See: https://www.spectralpython.net/class_func_ref.html?highlight=resampling#spectral.algorithms.resampling.BandResampler
# Inputs: the first input is the wavelengths for the spectra that you are going to resample, the second input is the wavelevngths that you want to resample to.
resampler = spectral.BandResampler(wl_lib, wl_im)
spectra_resampled = resampler(spectra.T).T

print(f'The shape of the spectral library is {spectra_resampled.shape}.')
print(f'({spectra_resampled.shape[0]} spectra with {spectra_resampled.shape[1]} bands.)')
# Out:
# The shape of the spectral library is (966, 372).
# (966 spectra with 372 bands.)

# %%
plt.figure(figsize=(12,5))
plt.title('An image spectrum with library spectra before and after resampling, showing band locations with markers.')
plt.plot(wl_im, imArr[100,100,:].flatten(), marker='.', label='Image Spectrum')
plt.plot(wl_lib, spectra[5,:].flatten(), marker='.', label='Orig Lib Spectrum')
plt.plot(wl_im, spectra_resampled[5,:].flatten(), marker='.', label='Resampled Lib Spectrum')
plt.xlabel('Wavelength (nm)')
plt.grid()
plt.legend();

# %%
# now that the library is resampled, let's use simple names.
spec = spectra_resampled # spectra from the library, after resampling
wl = wl_im # the wavelengths for the image and the resampled library

# %% [markdown]
# # Spectral Unmixing
#
# A *mixed pixel* in a hyperspectral image is a pixel that contains more than one pure material (a mixture of materials).
#
# The process of *unmixing* is the process of determining the pure materials and abuncances that are present in a mixed pixel.
#
# If $x$ is a mixed pixel spectrum and $S$ is an array of library or pixel spectra, then the linear mixing formula is:
#
# $$
# x= S \beta + \varepsilon
# $$
#
# This can be written as:
# $$
# \left[
#   \begin{array}{c}
#     s_1\\
#     s_2\\
#     \vdots\\
#     s_{nb}
#   \end{array}
# \right]
#  =
# \left[
#   \begin{array}{cccc}
#     S_{1,1} & S_{1,2} & \cdots & S_{1,k}\\
#     S_{2,1} & S_{2,2} & \cdots & S_{2,k}\\
#             & &  \vdots & & \\
#     S_{nb,1} & S_{nb,2} & \cdots & S_{nb,k}\\
#   \end{array}
# \right]
# \left[
#   \begin{array}{c}
#     \beta_1\\
#     \beta_2\\
#     \vdots\\
#     \beta_{nb}
#   \end{array}
# \right]
# +
# \left[
#   \begin{array}{c}
#     \varepsilon_1\\
#     \varepsilon_2\\
#     \vdots\\
#     \varepsilon_{nb}
#   \end{array}
# \right]
# $$
#
# Each coefficient in $\beta$ is the fraction of the mixed pixel spectrum that comes from the corresponding endmember. These must be positive. Optional added restrictions are that the coefficients sum to one or are all less than or equal to 1.
#
# We will use LinearRegression from sklean. Here are the inputs to the fit method:
#
# ![image.png](attachment:image.png)

# %%
# check the data shape
print(f'ImList shape: {imList.shape}')
print(f'Spectral Library spe shape: {spec.shape}')
X = spec.T
y = imList.T

print(f'Each library spectrum is a feature, so: n_features = {X.shape[1]} (number of predictor variables in each model)')
print(f'Each band is a sample, so: n_samples = {X.shape[0]} (number of observations in each model)')
print(f'Each pixel is a target, so: n_targets = {y.shape[1]} (number of regression models that we will build)')
# Out:
# ImList shape: (1100000, 372)
# Spectral Library spe shape: (966, 372)
# Each library spectrum is a feature, so: n_features = 966 (number of predictor variables in each model)
# Each band is a sample, so: n_samples = 372 (number of observations in each model)
# Each pixel is a target, so: n_targets = 1100000 (number of regression models that we will build)

# %%
### WHY DO WE NOT WANT TO DO THIS?

# load and fit a linear regression classifier
#clf = linear_model.LinearRegression(fit_intercept=False, copy_X=True, positive=True)
#clf.fit(X,y)

# %% [markdown]
# ## Unmixing, no coefficient restrictions

# %% [markdown]
# ## Unmixing with positive coefficients

# %%
# subset the library to use only a few spectra
library_indices = []
indicator_strings = ['dicktite', 'alunite', 'opal', 'monzonite', 'quartz', 'opal', 'buddingtonite', 'kaolunite']
for ind_str in indicator_strings:
    for i,name in enumerate(lib.names):
        if ind_str in name.lower():
            print([i, name.lower()])
            library_indices.append(int(i))

library_indices = np.asarray(library_indices)
library_indices = np.unique(library_indices)
library_indices = np.sort(library_indices)


X_select = X[:,library_indices]
names_sel = []
for i in library_indices:
    names_sel.append(names[i])
print(names_sel)
# Out:
# [284, 'alunite hs295.1b']
# [285, 'alunite hs295.3b']
# [286, 'alunite hs295.4b']
# [287, 'alunite hs295.6']
# [288, 'alunite hs295']
# [673, 'alunite+dickite mv99-6-26b']
# [674, 'alunite-k cu91-217g1 hitemp']
# [675, 'alunite0.35k+.65na cu91-217h']
# [676, 'alunite_k-na cu91-217h1 lowt']
# [677, 'alunite_k cu98-5c medtemp']
# [678, 'alunite_nh4+jaro nmnh145596a']
# [729, 'opalized tuff cu00-15e']
# [561, 'quartz hs32.1b']
# [562, 'quartz hs32.2b']
# [563, 'quartz hs32.3b']
# [711, 'illite cu00-5b hi-al+quartz']
# [729, 'opalized tuff cu00-15e']
# ['Alunite HS295.1B', 'Alunite HS295.3B', 'Alunite HS295.4B', 'Alunite HS295.6', 'Alunite HS295', 'Quartz HS32.1B', 'Quartz HS32.2B', 'Quartz HS32.3B', 'Alunite+Dickite MV99-6-26b', 'Alunite-K CU91-217G1 HiTemp', 'Alunite0.35K+.65Na CU91-217H', 'Alunite_K-Na CU91-217H1 LowT', 'Alunite_K CU98-5C MedTemp', 'Alunite_NH4+Jaro NMNH145596A', 'Illite CU00-5B Hi-Al+Quartz', 'Opalized Tuff CU00-15E']

# %%
library_indices = [285,673,674,729,562]
X_select = X[:,library_indices]
names_sel = []
for i in library_indices:
    names_sel.append(names[i])
print(names_sel)
# Out:
# ['Alunite HS295.3B', 'Alunite+Dickite MV99-6-26b', 'Alunite-K CU91-217G1 HiTemp', 'Opalized Tuff CU00-15E', 'Quartz HS32.2B']

# %% [markdown]
# ## Unmixing, no coefficient restrictions

# %%
# load and fit a linear regression classifier
clf_unrestricted = linear_model.LinearRegression(fit_intercept=False, copy_X=True, positive=False)
clf_unrestricted.fit(X_select,y)
# Out:
# LinearRegression(fit_intercept=False)

# %%
res_unrestricted = clf_unrestricted.coef_
print(res.shape)

result_im_unrestricted = np.reshape(res_unrestricted, (im.nrows,im.ncols,len(names_sel)))
for i in range(len(names_sel)):
    plt.figure(figsize=(15,5))    
    plt.imshow(np.flip(np.rot90(result_im_unrestricted[:,:,i]), axis=0), cmap='jet')
    plt.gca().invert_yaxis()  
    plt.colorbar()
    plt.xlabel('Row');
    plt.ylabel('Column');
    plt.title(f'Abundance for {names_sel[i]}')

# %% [markdown]
# ## Unmixing, positive coefficients only

# %%
# load and fit a linear regression classifier
clf = linear_model.LinearRegression(fit_intercept=False, copy_X=True, positive=True)
clf.fit(X_select,y[:,:10000])
# Out:
# LinearRegression(fit_intercept=False, positive=True)

# %%
print(f'5 seconds for {10000} pixels')
print(f'Estimated time: {y.shape[1]*(5/10000)} seconds')
# Out:
# 5 seconds for 10000 pixels
# Estimated time: 550.0 seconds

# %%
# load and fit a linear regression classifier
clf = linear_model.LinearRegression(fit_intercept=False, copy_X=True, positive=True)
clf.fit(X_select,y)
# Out:
# LinearRegression(fit_intercept=False, positive=True)

# %%
res = clf.coef_
print(res.shape)

result_im = np.reshape(res, (im.nrows,im.ncols,len(names_sel)))
for i in range(len(names_sel)):
    plt.figure(figsize=(15,5))    
    plt.imshow(np.flip(np.rot90(result_im[:,:,i]), axis=0), cmap='jet')
    plt.gca().invert_yaxis()  
    plt.xlabel('Row');
    plt.ylabel('Column');
    plt.title(f'Abundance for {names_sel[i]}')

# %%
mineral_image = result_im[:,:,[1,3,4]]
plt.figure(figsize=(15,50))
plt.imshow(mineral_image)
