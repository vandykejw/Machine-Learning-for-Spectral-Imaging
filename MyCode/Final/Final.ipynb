# %%
#%pip install --upgrade hyperspectral_gta_data

# %%
# Common useful packages
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import copy
import spectral

# module that is useful for reloading packages
import importlib

import sys
sys.path.append('/workspaces/Machine-Learning-for-Spectral-Imaging/MyCode/HW/')

sys.path.append('/workspaces/Machine-Learning-for-Spectral-Imaging/Book_Modules/')

# Scripts associated with the SML4SI textbook
import hyperspectral_gta_data as hsi_data
import scripts_M2 as sm2

# set the directory where data will be downloaded and accessed
# (This directory will be saved in a config file and used each time you use hyperspectral_gta_data, 
# so you don't need to run the 'set_data_dir' function every time you use hyperspectral_gta_data.)
hsi_data.set_data_dir('/workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/')

# %% [markdown]
# ## In this notebook, we will introduce target detection.
#
# With target detection, we have two data sets:
# 1. **A hyperspectral image.**
# 2. **Target spectra.**
#
# The target spectra are usually collected from known materials that we want to find in the iamge.
#
# The data preparation includes:
# 1. **Load Data:** Load the image and spectral library.
# 2. **Check Data Scale:** Check that the iamge and library have the same scale. Ideally, they are both on a 0-1 scale for reflectance units, but:
#     i. Sometimes data are stored in 16-bit integer data type to save memory and resources.  In that case, they are often on a 0-1000 scale.
#     ii. Often, the values for spectral data are too large or small due to (1) changes in sunlight and shadow, (2) problems in atmospherice correction, converting from radiance to reflectance, or (3) calibration of sensors.
# 3. **Check Wavelengths:** Check that the image and spectra have wavelengths in the same units (both nanometers or both micrometers) and have the same values.  If the units are different, we simply multiply or divide by 1000 as needed.  If the wavelength values are different, we have to resample the data. Almost always, this means resampling the library to the wavelengths of the image, because the library usually has higher spectral resolution (more bands with more tightly-spaced wavelengths).
# 4. **Quality Check:** Do a quality check on the data and spectra.  If the light source for either is the sun, then there will be bands where the atmosphere (mostly water vapor) absorbs most of the light.  These need to be removed from the data, and then the resampling is needed as in Step 3.
#
# After these are completed, we will be ready for target deteciton.

# %% [markdown]
# # 1. Download the data

# %%
# Here are the datasets available through the hyperspectral_gta_data package
hsi_data.available_datasets()
# Out:
# Available Images:
#    WashingtonDC
#    MicroscenePolymers
#    Detection_Imagery_Cooke_City_RIT
#    VegBaccharisUPWINS
#    PaintDetectionUPWINS
#    indian_pines
#    pavia_centre
#    pavia_university
# Available Spectral Libraries:
#    GHISACONUS_2008_001_speclib
#    Microscene_Polymers_Library
#    UPWINS_4_16_2024
#    Detection_Library_Cooke_City_RIT

# %% [markdown]
# ## Download the hyperspectral image
#
# In this case, we will be using a hyperspectral image from the RIT test over Cooke City, Montana. (https://dirsapps.cis.rit.edu/blindtest/)

# %%
# Download and use the Cooke Cite image:
hsi_data.download('VegBaccharisUPWINS')
fname = hsi_data.get_fname('VegBaccharisUPWINS')
# Out:
# Available Files:
# /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_images/Vegetation_Baccharis_halmifolia_UPWINS/Morven_Baccharis_h_or_ref.hdr
# /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_images/Vegetation_Baccharis_halmifolia_UPWINS/Morven_Baccharis_h_or_ref
# Primary Image Filename:
# /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_images/Vegetation_Baccharis_halmifolia_UPWINS/Morven_Baccharis_h_or_ref

# %%
# load the UPWINS hyperspectral iamge
fname = '/workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_images/Vegetation_Baccharis_halmifolia_UPWINS/Morven_Baccharis_h_or_ref'
fname_hdr = '/workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_images/Vegetation_Baccharis_halmifolia_UPWINS/Morven_Baccharis_h_or_ref.hdr'

# Open the image and read into an array
im = spectral.envi.open(fname_hdr, fname)
wl_im = np.asarray(im.bands.centers)
# Load the image into memory
im.Arr = im.load()
imArr = im.Arr
print(f'Shape of ImArr = {imArr.shape}')
imList = np.reshape(imArr, (im.nrows*im.ncols, im.nbands))
print(f'Shape of imList = {imList.shape}')
# Out:
# Shape of ImArr = (300, 600, 343)
# Shape of imList = (180000, 343)

# %%
# display the image
sm2.display_RGB(imArr, wl_im, rotate=False)
plt.title('RGB Image');

# %%
# explore the image in our hyperspectral image viewer
from hsiViewer import hsi_viewer as hv
#hv.viewer(im)

# %% [markdown]
# # Download the Spectral Library fopr Target Detection

# %%
# To download and use the Cooke City spectral library image:
hsi_data.download('UPWINS_4_16_2024')
fname = hsi_data.get_fname('UPWINS_4_16_2024')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11Zn-DxlVevtg-KAKnDRiPEVxnLYXDl5h
# To: /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024.zip
# 100%|██████████| 6.88M/6.88M [00:03<00:00, 2.03MB/s]
# File saved as: /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024/UPWINS_4_16_2024.hdr
# File saved as: /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024/UPWINS_4_16_2024.sli
#
# Available Files:
# /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024/UPWINS_4_16_2024.sli
# /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024/UPWINS_4_16_2024.hdr
# Primary Image Filename:
# /workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024/UPWINS_4_16_2024.sli

# %%
fname = '/workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024/UPWINS_4_16_2024.sli'
fname_hdr = '/workspaces/Machine-Learning-for-Spectral-Imaging/spectral_data/spectral_libraries/UPWINS_4_16_2024/UPWINS_4_16_2024.hdr'

# Open the image and read into an array
lib = spectral.envi.open(fname_hdr, fname)
wl = np.asarray(im.bands.centers)
# Load the image into memory
names = lib.names
spectra = lib.spectra
wl_lib = np.asarray(lib.bands.centers)

# %%
names
# Out:
# ['Baccharis_Halimif_L_Y1G_H00000',
#  'Baccharis_Halimif_L_Y1G_H00001',
#  'Baccharis_Halimif_L_Y1G_H00002',
#  'Baccharis_Halimif_L_Y1G_H00003',
#  'Baccharis_Halimif_L_Y1G_H00004',
#  'Baccharis_Halimif_L_Y1G_H00005',
#  'Baccharis_Halimif_L_Y1G_H00006',
#  'Baccharis_Halimif_L_Y1G_H00007',
#  'Baccharis_Halimif_L_Y1G_H00008',
#  'Baccharis_Halimif_L_Y1G_H00009',
#  'Baccharis_Halimif_L_Y1G_H00010',
#  'Baccharis_Halimif_L_Y1G_H00011',
#  'Baccharis_Halimif_L_Y1G_H00012',
#  'Baccharis_Halimif_L_Y1G_H00013',
#  'Baccharis_Halimif_L_Y1G_H00014',
#  'Baccharis_Halimif_L_Y1G_H00015',
#  'Baccharis_Halimif_L_Y1G_H00016',
#  'Baccharis_Halimif_L_Y1G_H00017',
#  'Baccharis_Halimif_L_Y1G_H00018',
#  'Baccharis_Halimif_L_Y1G_H00019',
#  'Baccharis_Halimif_L_Y1G_H00020',
#  'Baccharis_Halimif_RS_Y1G_H00000',
#  'Baccharis_Halimif_RS_Y1G_H00001',
#  'Baccharis_Halimif_RS_Y1G_H00002',
#  'Baccharis_Halimif_SA_Y1G_H00000',
#  'Baccharis_Halimif_SA_Y1G_H00001',
#  'Baccharis_Halimif_SA_Y1G_H00002',
#  'Baccharis_halimifoli_L_RE_H00000',
#  'Baccharis_halimifoli_L_RE_H00001',
#  'Baccharis_halimifoli_L_RE_H00002',
#  'Baccharis_halimifoli_L_RE_H00003',
#  'Chamdecrista_fasc_sprout00000',
#  'Chamdecrista_fasc_sprout00001',
#  'Chamdecrista_fasc_sprout00002',
#  'Chamdecrista_fasc_sprout00003',
#  'Chamdecrista_fasc_sprout00004',
#  'Chamdecrista_fasc_sprout00005',
#  'Chamdecrista_fasc_sprout00006',
#  'Chamdecrista_fasc_sprout00007',
#  'Chamdecrista_fasc_sprout00008',
#  'Chasmanthiu_latifoli_L_RE_H00000',
#  'Chasmanthiu_latifoli_L_RE_H00001',
#  'Chasmanthiu_latifoli_L_RE_H00002',
#  'ChasmanthiumLatifolium_Blad00000',
#  'ChasmanthiumLatifolium_Blad00001',
#  'ChasmanthiumLatifolium_Blad00002',
#  'ChasmanthiumLatifolium_Mix00000',
#  'ChasmanthiumLatifolium_Mix00001',
#  'ChasmanthiumLatifolium_Mix00002',
#  'ChasmanthiumLatifolium_Mix00003',
#  'ChasmanthiumLatifolium_Mix00004',
#  'ChasmanthiumLatifolium_Mix00005',
#  'ChasmanthiumLatifolium_Mix00006',
#  'ChasmanthiumLatifolium_Mix00007',
#  'ChasmanthiumLatifolium_Mix00008',
#  'ChasmanthiumLatifolium_Mix00009',
#  'ChasmanthiumLatifolium_Mix00010',
#  'ChasmanthiumLatifolium_Mix00011',
#  'Chasmanthium_lati_healthy00000',
#  'Chasmanthium_lati_healthy00001',
#  'Chasmanthium_lati_healthy00002',
#  'Chasmanthium_lati_scenesced00000',
#  'Chasmanthium_lati_scenesced00001',
#  'Chasmanthium_lati_scenesced00002',
#  'Chasmanthium_lati_scenesced00003',
#  'Chasmanthium_lati_scenesced00004',
#  'Chasmanthium_lati_scenesced00005',
#  'Chasmanthium_latifol_B_E_H00000',
#  'Chasmanthium_latifol_B_E_H00001',
#  'Chasmanthium_latifol_B_E_H00002',
#  'Chasmanthium_latifol_B_E_H00003',
#  'Chasmanthium_latifol_B_E_H00004',
#  'Chasmanthium_latifol_B_E_H00005',
#  'IlexVomitoria_bark00000',
#  'IlexVomitoria_bark00001',
#  'IlexVomitoria_bark00002',
#  'IlexVomitoria_leaf00000',
#  'IlexVomitoria_leaf00001',
#  'IlexVomitoria_leaf00002',
#  'IlexVomitoria_leaf00003',
#  'IlexVomitoria_leaf00004',
#  'IlexVomitoria_leaf00005',
#  'IlexVomitoria_mix00000',
#  'IlexVomitoria_mix00001',
#  'IlexVomitoria_mix00002',
#  'IlexVomitoria_mix00003',
#  'IlexVomitoria_mix00004',
#  'IlexVomitoria_mix00005',
#  'IlexVomitoria_mix00006',
#  'IlexVomitoria_mix00007',
#  'IlexVomitoria_mix00008',
#  'IlexVomitoria_mix00009',
#  'IlexVomitoria_mix00010',
#  'IlexVomitoria_mix00011',
#  'IlexVomitoria_mix00012',
#  'IlexVomitoria_mix00013',
#  'IlexVomitoria_mix00014',
#  'IlexVomitoria_mix00015',
#  'IlexVomitoria_mix00016',
#  'IlexVomitoria_mix00017',
#  'Ilex_vomitoria_L_E_H00000',
#  'Ilex_vomitoria_L_E_H00001',
#  'Ilex_vomitoria_L_E_H00002',
#  'Ilex_vomitoria_L_RE_H00000',
#  'Ilex_vomitoria_L_RE_H00001',
#  'Ilex_vomitoria_L_RE_H00002',
#  'Ilex_vomitoria_leaf_bottom00000',
#  'Ilex_vomitoria_leaf_bottom00001',
#  'Ilex_vomitoria_leaf_bottom00002',
#  'Ilex_vomitoria_leaf_bottom00003',
#  'Ilex_vomitoria_leaf_bottom00004',
#  'Ilex_vomitoria_leaf_bottom00005',
#  'Ilex_vomitoria_leaf_top00000',
#  'Ilex_vomitoria_leaf_top00001',
#  'Ilex_vomitoria_leaf_top00002',
#  'Ilex_vomitoria_leaf_top00003',
#  'Ilex_vomitoria_leaf_top00004',
#  'Ilex_vomitoria_leaf_top00005',
#  'Ilex_vomitoria_mix00000',
#  'Ilex_vomitoria_mix00001',
#  'Ilex_vomitoria_mix00002',
#  'Iva_frutescens_CS_RE_H00000',
#  'Iva_frutescens_CS_RE_H00001',
#  'Iva_frutescens_CS_RE_H00002',
#  'Iva_frutescens_CS_RE_H00003',
#  'Iva_frutescens_CS_RE_H00004',
#  'Iva_frutescens_CS_RE_H00005',
#  'Iva_frutescens_CS_RE_H00006',
#  'Iva_frutescens_CS_RE_H00007',
#  'Iva_frutescens_CS_RE_H00008',
#  'Iva_frutescens_L_RE_H00000',
#  'Iva_frutescens_L_RE_H00001',
#  'Iva_frutescens_L_RE_H00002',
#  'Iva_frutescens_L_RE_H00003',
#  'Iva_frutescens_L_RE_H00004',
#  'Iva_frutescens_L_RE_H00005',
#  'Iva_frutescens_L_RE_H00006',
#  'Iva_frutescens_L_RE_H00007',
#  'Iva_frutescens_L_RE_H00008',
#  'Iva_frutescens_L_RE_H00009',
#  'Iva_frutescens_L_RE_H00010',
#  'Iva_frutescens_L_RE_H00011',
#  'Iva_frutescens_L_RE_LLRZ00000',
#  'Iva_frutescens_L_RE_LLRZ00001',
#  'Iva_frutescens_L_RE_LLRZ00002',
#  'Iva_frutescens_L_RE_LLRZ00003',
#  'Iva_frutescens_L_RE_LLRZ00004',
#  'Iva_frutescens_L_RE_LLRZ00005',
#  'Iva_frutescens_L_RE_LLRZ00006',
#  'Iva_frutescens_L_RE_LLRZ00007',
#  'Iva_frutescens_L_RE_LLRZ00008',
#  'Iva_frutescens_L_RE_LLRZ00009',
#  'Iva_frutescens_L_RE_LLRZ00010',
#  'Iva_frutescens_L_RE_LLRZ00011',
#  'Iva_frutescens_L_RE_S100000',
#  'Iva_frutescens_L_RE_S100001',
#  'Iva_frutescens_L_RE_S100002',
#  'Iva_frutescens_L_RE_S100003',
#  'Iva_frutescens_L_RE_S100004',
#  'Iva_frutescens_L_RE_S100005',
#  'Iva_frutescens_L_RE_W00000',
#  'Iva_frutescens_L_RE_W00001',
#  'Iva_frutescense_L_RE_H00000',
#  'Iva_frutescense_L_RE_H00001',
#  'Iva_frutescense_L_RE_H00002',
#  'Iva_frutescense_L_RE_H00003',
#  'Iva_frutescense_S_RE_H00000',
#  'Iva_frutescense_S_RE_H00001',
#  'Iva_frutescense_S_RE_W00000',
#  'PanicumVirgatum_Blade00000',
#  'PanicumVirgatum_Blade00001',
#  'PanicumVirgatum_Blade00002',
#  'PanicumVirgatum_Blade00003',
#  'PanicumVirgatum_Blade00004',
#  'PanicumVirgatum_Blade00005',
#  'PanicumVirgatum_Mix00000',
#  'PanicumVirgatum_Mix00001',
#  'PanicumVirgatum_Mix00002',
#  'PanicumVirgatum_Mix00003',
#  'PanicumVirgatum_Mix00004',
#  'PanicumVirgatum_Mix00005',
#  'PanicumVirgatum_Mix00006',
#  'PanicumVirgatum_Mix00007',
#  'PanicumVirgatum_Mix00008',
#  'Panicum_amarum_B_E_H00000',
#  'Panicum_amarum_B_E_H00001',
#  'Panicum_amarum_B_E_H00002',
#  'Panicum_amarum_B_E_H00003',
#  'Panicum_amarum_B_E_H00004',
#  'Panicum_amarum_B_E_H00005',
#  'Panicum_amarum_B_E_H00006',
#  'Panicum_amarum_B_E_H00007',
#  'Panicum_amarum_B_E_H00008',
#  'Panicum_amarum_B_E_H00009',
#  'Panicum_amarum_B_E_H00010',
#  'Panicum_amarum_B_E_H00011',
#  'Panicum_amarum_B_E_H00012',
#  'Panicum_amarum_B_E_H00013',
#  'Panicum_amarum_B_E_H00014',
#  'Panicum_amarum_B_E_H00015',
#  'Panicum_amarum_B_E_H00016',
#  'Panicum_amarum_B_E_H00017',
#  'Panicum_amarum_L_RE_H00000',
#  'Panicum_amarum_L_RE_H00001',
#  'Panicum_amarum_L_RE_H00002',
#  'Panicum_amarum_L_RE_H00003',
#  'Panicum_virgatum_B_E_H00000',
#  'Panicum_virgatum_B_E_H00001',
#  'Panicum_virgatum_B_E_H00002',
#  'Panicum_virgatum_B_E_H00003',
#  'Panicum_virgatum_B_E_H00004',
#  'Panicum_virgatum_B_E_H00005',
#  'Panicum_virgatum_L_RE_H00000',
#  'Panicum_virgatum_L_RE_H00001',
#  'Panicum_virgatum_L_RE_H00002',
#  'Panicum_virgatum_L_RE_H00003',
#  'Panicum_virgatum_leaf_botto00000',
#  'Panicum_virgatum_leaf_botto00001',
#  'Panicum_virgatum_leaf_botto00002',
#  'Panicum_virgatum_leaf_top00000',
#  'Panicum_virgatum_leaf_top00001',
#  'Panicum_virgatum_leaf_top00002',
#  'Panicum_virgatum_scenesced00000',
#  'Panicum_virgatum_scenesced00001',
#  'Panicum_virgatum_scenesced00002',
#  'Panicum_virgatum_sprout00000',
#  'Panicum_virgatum_sprout00001',
#  'Panicum_virgatum_sprout00002',
#  'Panicum_virgatum_sprout00003',
#  'Panicum_virgatum_sprout00004',
#  'Panicum_virgatum_sprout00005',
#  'Panicum_virgatum_sprout00006',
#  'Panicum_virgatum_sprout00007',
#  'Panicum_virgatum_sprout00008',
#  'PartridgePea_flowering00000',
#  'PartridgePea_flowering00001',
#  'PartridgePea_flowering00002',
#  'PartridgePea_flowering00003',
#  'PartridgePea_flowering00004',
#  'PartridgePea_flowering00005',
#  'PartridgePea_flowering00006',
#  'PartridgePea_flowering00007',
#  'PartridgePea_flowering00008',
#  'Rosa_rugosa_L_Y1G_H00000',
#  'Rosa_rugosa_L_Y1G_H00001',
#  'Rosa_rugosa_L_Y1G_H00002',
#  'Rosa_rugosa_L_Y1G_H00003',
#  'Rosa_rugosa_L_Y1G_H00004',
#  'Rosa_rugosa_L_Y1G_H00005',
#  'Rosa_rugosa_L_Y1G_H00006',
#  'Rosa_rugosa_L_Y1G_H00007',
#  'Rosa_rugosa_L_Y1G_H00008',
#  'Rosa_rugosa_L_Y1G_H00009',
#  'Rosa_rugosa_L_Y1G_H00010',
#  'Rosa_rugosa_L_Y1G_H00011',
#  'Rosa_rugosa_L_Y1G_H00012',
#  'Rosa_rugosa_L_Y1G_H00013',
#  'Rosa_rugosa_L_Y1G_H00014',
#  'Rosa_rugosa_L_Y1G_LLRZ00000',
#  'Rosa_rugosa_L_Y1G_LLRZ00001',
#  'Rosa_rugosa_L_Y1G_LLRZ00002',
#  'Rosa_rugosa_L_Y1G_LLRZ00003',
#  'Rosa_rugosa_L_Y1G_LLRZ00004',
#  'Rosa_rugosa_L_Y1G_LLRZ00005',
#  'Rosa_rugosa_L_Y1G_LLRZ00006',
#  'Rosa_rugosa_L_Y1G_LLRZ00007',
#  'Rosa_rugosa_L_Y1G_S00000',
#  'Rosa_rugosa_L_Y1G_S00001',
#  'Rosa_rugosa_L_Y1G_S00002',
#  'Rosa_rugosa_L_Y1G_S00003',
#  'Rosa_rugosa_L_Y1G_S00004',
#  'Rosa_rugosa_SA_Y1G_H00000',
#  'Rosa_rugosa_SA_Y1G_H00001',
#  'Rosa_rugosa_SA_Y1G_H00002',
#  'Rosa_rugosa_SA_Y1G_H00003',
#  'Rosa_rugosa_SA_Y1G_H00004',
#  'Rosa_rugosa_SA_Y1G_H00005',
#  'Rosa_rugosa_SA_Y1G_H00006',
#  'Rosa_rugosa_SA_Y1G_H00007',
#  'Rosa_rugosa_SA_Y1G_H00008',
#  'Solidago_rugosa_L_E_H00000',
#  'Solidago_rugosa_L_E_H00001',
#  'Solidago_rugosa_L_E_H00002',
#  'Solidago_rugosa_L_E_H00003',
#  'Solidago_rugosa_L_E_H00004',
#  'Solidago_rugosa_L_E_H00005',
#  'Solidago_rugosa_L_E_H00006',
#  'Solidago_rugosa_L_E_H00007',
#  'Solidago_rugosa_L_E_H00008',
#  'Solidago_rugosa_L_Y1G_H00000',
#  'Solidago_rugosa_L_Y1G_H00001',
#  'Solidago_rugosa_L_Y1G_H00002',
#  'Solidago_rugosa_L_Y1G_H00003',
#  'Solidago_rugosa_L_Y1G_H00004',
#  'Solidago_rugosa_L_Y1G_H00005',
#  'Solidago_semp_with_bleach00000',
#  'Solidago_semp_with_bleach00001',
#  'Solidago_semp_with_res00000',
#  'Solidago_semperv_L_Y1G_H00000',
#  'Solidago_semperv_L_Y1G_H00001',
#  'Solidago_semperv_L_Y1G_H00002',
#  'Solidago_semperv_L_Y1G_H00003',
#  'Solidago_semperv_L_Y1G_H00004',
#  'Solidago_semperv_L_Y1G_H00005',
#  'Solidago_semperv_L_Y1G_H00006',
#  'Solidago_semperv_L_Y1G_H00007',
#  'Solidago_semperv_L_Y1G_H00008',
#  'Solidago_semperv_L_Y1G_H00009',
#  'Solidago_semperv_L_Y1G_H00010',
#  'Solidago_semperv_L_Y1G_H00011',
#  'Solidago_semperv_L_Y1G_H00012',
#  'Solidago_semperv_L_Y1G_H00013',
#  'Solidago_semperv_L_Y1G_LLRZ00000',
#  'Solidago_semperv_L_Y1G_LLRZ00001',
#  'Solidago_semperv_L_Y1G_LLRZ00002',
#  'Solidago_semperv_L_Y1G_LLRZ00003',
#  'Solidago_semperv_L_Y1G_LLRZ00004',
#  'Solidago_semperv_L_Y1G_LLRZ00005',
#  'Solidago_semperv_L_Y1G_LLRZ00006',
#  'Solidago_semperv_L_Y1G_LLRZ00007',
#  'Solidago_semperv_L_Y1G_LLRZ00008',
#  'Solidago_semperv_L_Y1G_LLRZ00009',
#  'Solidago_semperv_L_Y1G_LLRZ00010',
#  'Solidago_semperv_L_Y1G_LLRZ00011',
#  'Solidago_semperv_L_Y1G_S00000',
#  'Solidago_semperviren_L_RE_H00000',
#  'Solidago_semperviren_L_RE_H00001',
#  'Solidago_semperviren_L_RE_H00002',
#  'Solidago_semperviren_L_RE_H00003',
#  'Solidago_semperviren_L_RE_H00004',
#  'Solidago_semperviren_L_RE_H00005',
#  'Solidago_semperviren_L_RE_H00006',
#  'Solidago_semperviren_L_RE_H00007',
#  'Solidago_semperviren_L_RE_H00008',
#  'Solidago_semperviren_L_RE_H00009',
#  'Solidago_semperviren_S_RE_H00000',
#  'Solidago_semperviren_S_RE_H00001',
#  'Solidago_semperviren_S_RE_H00002',
#  'Solidago_sempervirens_rust00000',
#  'Solidago_sempervirens_rust00001',
#  'Solidago_sempervirens_rust00002',
#  'Solidago_sempervirens_rust00003',
#  'Solidago_sempervirens_rust00004',
#  'Solidago_sempervirens_rust00005',
#  'Solidago_sempervirens_rust00006',
#  'Solidago_sempervirens_rust00007',
#  'Solidago_sempervirens_rust00008',
#  'Solidago_sempervirens_rust00009',
#  'Solidago_sempervirens_rust00010',
#  'Solidago_sempervirens_rust00011',
#  'Solidago_sempervirens_rust00012',
#  'Solidago_sempervirens_rust00013',
#  'Solidago_sempervirens_rust00014',
#  'Solidago_sempreviren_L_RE_H00000',
#  'Solidago_sempreviren_L_RE_H00001',
#  'Solidago_sempreviren_L_RE_H00002',
#  'Solidago_sempreviren_L_RE_H00003',
#  'Solidago_sempreviren_L_RE_H00004',
#  'Solidago_sempreviren_L_RE_H00005',
#  'beachgrass_mature00000',
#  'beachgrass_mature00001',
#  'beachgrass_mature00002',
#  'beachgrass_mature00003',
#  'beachgrass_mature00004',
#  'beachgrass_mature00005',
#  'beachgrass_mature00006',
#  'beachgrass_mature00007',
#  'beachgrass_midseason00000',
#  'beachgrass_midseason00001',
#  'beachgrass_midseason00002',
#  'beachgrass_midseason00003',
#  'beachgrass_midseason00004',
#  'beachgrass_midseason00005',
#  'beachgrass_midseason00006',
#  'beachgrass_midseason00007',
#  'beachgrass_midseason00008',
#  'beachgrass_midseason00009',
#  'beachgrass_midseason00010',
#  'beachgrass_midseason00011',
#  'beachgrass_midseason00012',
#  'beachgrass_midseason00013',
#  'beachgrass_midseason00014',
#  'beachgrass_midseason00015',
#  'beachgrass_midseason00016',
#  'beachgrass_midseason00017',
#  'beachgrass_midseason00018',
#  'beachgrass_midseason00019',
#  'beachgrass_midseason00020',
#  'beachgrass_midseason00021',
#  'grass_coolSeason_scenesed00000',
#  'grass_coolSeason_scenesed00001',
#  'grass_coolSeason_scenesed00002',
#  'grass_coolSeason_scenesed00003',
#  'grass_coolSeason_scenesed00004',
#  'gravel_road00000',
#  'gravel_road00001',
#  'gravel_road00002',
#  'gravel_road00003',
#  'gravel_road00004',
#  'gravel_road00005',
#  'gravel_road00006',
#  'gravel_road00007',
#  'gravel_road00008',
#  'gravel_road00009',
#  'gravel_road00010',
#  'gravel_road00011',
#  'gravel_road00012',
#  'gravel_road00013',
#  'gravel_road00014',
#  'gravel_road00015',
#  'gravel_road00016',
#  'gravel_road00017',
#  'gravel_road00018',
#  'gravel_road00019',
#  'gravel_road00020',
#  'gravel_road00021',
#  'gravel_road00022',
#  'gravel_road00023',
#  'gravel_road00024',
#  'manmade_cardboard_00000',
#  'manmade_cardboard_00001',
#  'manmade_cardboard_black_00000',
#  'manmade_cardboard_black_00001',
#  'manmade_paper_00000',
#  'manmade_paper_black_00000',
#  'manmade_paper_black_00001',
#  'manmade_paper_halfblack_00000',
#  'manmade_paper_halfblack_00001',
#  'manmade_paper_halfblack_00002',
#  'manmade_polymer_HDPE_00000',
#  'manmade_polymer_HDPE_00001',
#  'manmade_polymer_HDPE_00002',
#  'manmade_polymer_HDPE_00003',
#  'manmade_polymer_HDPE_00004',
#  'manmade_polymer_PVC_00000',
#  'manmade_polymer_PVC_00001',
#  'manmade_polymer_PVC_00002',
#  'manmade_polymer_PVC_00003',
#  'manmade_polymer_PVC_00004',
#  'manmade_polymer_PVC_00005',
#  'manmade_polymer_PVC_00006',
#  'manmade_polymer_PVC_00007',
#  'manmade_polymer_PVC_00008',
#  'manmade_polymer_PVC_00009',
#  'manmade_polymer_styrene_ABS_00000',
#  'manmade_polymer_styrene_ABS_00001',
#  'manmade_polymer_styrene_ABS_00002',
#  'manmade_polymer_styrene_ABS_00003',
#  'manmade_polymer_styrene_ABS_00004',
#  'manmade_polyurethyneOnWood_00000',
#  'manmade_polyurethyneOnWood_00001',
#  'manmade_polyurethyneOnWood_00002',
#  'manmade_polyurethyneOnWood_00003',
#  'manmade_polyurethyneOnWood_00004',
#  'manmade_vehicle_truck_paint_Tacoma_black_00000',
#  'manmade_vehicle_truck_paint_Tacoma_black_00001',
#  'manmade_vehicle_truck_paint_Tacoma_black_00002',
#  'manmade_vehicle_truck_paint_Tacoma_black_00003',
#  'manmade_vehicle_truck_paint_Tacoma_black_00004',
#  'milkweed_midseason00000',
#  'milkweed_midseason00001',
#  'milkweed_midseason00002',
#  'milkweed_midseason00003',
#  'milkweed_midseason00004',
#  'milkweed_midseason00005',
#  'mineral_alunite_00000',
#  'mineral_alunite_00001',
#  'mineral_alunite_00002',
#  'mineral_calcite_orangeCalcite_00000',
#  'mineral_calcite_orangeCalcite_00001',
#  'mineral_calcite_orangeCalcite_00002',
#  'mineral_calcite_orangeCalcite_00003',
#  'mineral_calcite_orangeCalcite_00004',
#  'mineral_quartz_amethyst_00000',
#  'mineral_quartz_amethyst_00001',
#  'mineral_quartz_amethyst_00002',
#  'mineral_quartz_amethyst_00003',
#  'mineral_quartz_amethyst_00004',
#  'mineral_quartz_milkyquartz_00000',
#  'mineral_quartz_milkyquartz_00001',
#  'mineral_quartz_milkyquartz_00002',
#  'mineral_quartz_milkyquartz_00003',
#  'mineral_quartz_milkyquartz_00004',
#  'mineral_salt_00000',
#  'mineral_salt_00001',
#  'mineral_salt_00002',
#  'mineral_salt_00003',
#  'mineral_salt_00004',
#  'mineral_salt_00005',
#  'mineral_salt_00006',
#  'mineral_salt_00007',
#  'mineral_salt_00008',
#  'mineral_salt_00009',
#  'sand_quartz_golf_course00000',
#  'sand_quartz_golf_course00001',
#  'sand_quartz_golf_course00002',
#  'sand_quartz_golf_course00003',
#  'sand_quartz_golf_course00004',
#  'soil_PlotA_00000',
#  'soil_PlotA_00001',
#  'soil_PlotA_00002',
#  'soil_PlotA_00003',
#  'soil_PlotA_00004',
#  'soil_PlotA_00005',
#  'soil_PlotA_00006',
#  'soil_PlotA_00007',
#  'soil_PlotA_00008',
#  'soil_PlotA_00009',
#  'soil_PlotA_00010',
#  'soil_PlotA_00011',
#  'soil_PlotA_00012',
#  'soil_PlotA_00013',
#  'soil_PlotA_00014',
#  'soil_PlotB_00000',
#  'soil_PlotB_00001',
#  'soil_PlotB_00002',
#  'soil_PlotB_00003',
#  'soil_PlotB_00004',
#  'soil_PlotB_00005',
#  'soil_PlotB_00006',
#  'soil_PlotB_00007',
#  'soil_PlotB_00008',
#  'soil_PlotB_00009',
#  'soil_PlotB_00010',
#  'soil_PlotB_00011',
#  'soil_PlotB_00012',
#  'soil_PlotB_00013',
#  'soil_PlotB_00014',
#  'soil__Morven1_BG_00000',
#  'soil__Morven1_BG_00001',
#  'soil__Morven1_BG_00002',
#  'soil__Morven1_BG_00003',
#  'soil__Morven1_BG_00004',
#  'soil__Morven1_BG_00005',
#  'soil__Morven1_BG_00006',
#  'soil__Morven1_BG_00007',
#  'soil__Morven1_BG_00008',
#  'soil__Morven1_BG_00009',
#  'soil_sand_quartz_golfCourse_00000',
#  'soil_sand_quartz_golfCourse_00001',
#  'soil_sand_quartz_golfCourse_00002',
#  'soil_sand_quartz_golfCourse_00003',
#  'soil_sand_quartz_golfCourse_00004',
#  'specrral_reference_panel00000',
#  'specrral_reference_panel00001',
#  'specrral_reference_panel00002',
#  'specrral_reference_panel00003',
#  'specrral_reference_panel00004',
#  'specrral_reference_panel00005',
#  'specrral_reference_panel00006',
#  'specrral_reference_panel00007',
#  'specrral_reference_panel00008',
#  'specrral_reference_panel00009',
#  'styrafoam_ref00000',
#  'styrafoam_ref00001',
#  'styrafoam_ref00002',
#  'styrafoam_ref00003',
#  'styrafoam_ref00004',
#  'sugar_granulated_00000',
#  'sugar_granulated_00001',
#  'sugar_granulated_00002',
#  'sugar_granulated_00003',
#  'sugar_granulated_00004',
#  'veg_mugwart_midseaseon00000',
#  'veg_mugwart_midseaseon00001',
#  'veg_mugwart_midseaseon00002',
#  'veg_mugwart_midseaseon00003',
#  'veg_mugwart_midseaseon00004',
#  'veg_mugwart_midseaseon00005',
#  'veg_mugwart_midseaseon00006',
#  'veg_mugwart_midseaseon00007',
#  'veg_mugwart_midseaseon00008',
#  'veg_mugwart_midseaseon00009',
#  'veg_mugwart_midseaseon00010',
#  'veg_mugwart_midseaseon00011',
#  'veg_mugwart_midseaseon00012',
#  'veg_mugwart_midseaseon00013',
#  'veg_mugwart_midseaseon00014',
#  'veg_mugwart_midseaseon00015',
#  'veg_mugwart_midseaseon00016',
#  'veg_mugwart_midseaseon00017',
#  'veg_mugwart_midseaseon00018',
#  'veg_mugwart_midseaseon00019',
#  'veg_mugwart_midseaseon00020',
#  'veg_mugwart_midseaseon00021',
#  'veg_mugwart_midseaseon00022',
#  'veg_mugwart_midseaseon00023',
#  'veg_mugwart_midseaseon00024',
#  'vegetation_backrounds00000',
#  'vegetation_backrounds00001',
#  'vegetation_backrounds00002',
#  'vegetation_backrounds00003',
#  'vegetation_backrounds00004',
#  'vegetation_backrounds00005',
#  'vegetation_backrounds00006',
#  'vegetation_backrounds00007',
#  'vegetation_backrounds00008',
#  'vegetation_backrounds00009',
#  'vegetation_backrounds00010',
#  'vegetation_backrounds00011',
#  'vegetation_backrounds00012',
#  'vegetation_backrounds00013',
#  'vegetation_backrounds00014',
#  'vegetation_backrounds00015',
#  'vegetation_backrounds00016',
#  'vegetation_backrounds00017',
#  'vegetation_backrounds00018',
#  'vegetation_backrounds00019',
#  'vegetation_backrounds00020',
#  'vegetation_backrounds00021',
#  'vegetation_backrounds00022',
#  'vegetation_backrounds00023',
#  'vegetation_backrounds00024',
#  'vegetation_beachgrass_dormant_leaf_00000',
#  'vegetation_beachgrass_dormant_leaf_00001',
#  'vegetation_beachgrass_dormant_leaf_00002',
#  'vegetation_beachgrass_dormant_leaf_00003',
#  'vegetation_beachgrass_dormant_leaf_00004',
#  'vegetation_beachgrass_dormant_leaf_00005',
#  'vegetation_beachgrass_dormant_leaf_00006',
#  'vegetation_beachgrass_dormant_leaf_00007',
#  'vegetation_beachgrass_dormant_leaf_00008',
#  'vegetation_beachgrass_dormant_leaf_00009',
#  'vegetation_beachgrass_dormant_leaf_00010',
#  'vegetation_beachgrass_dormant_leaf_00011',
#  'vegetation_beachgrass_dormant_leaf_00012',
#  'vegetation_beachgrass_dormant_leaf_00013',
#  'vegetation_beachgrass_dormant_leaf_00014',
#  'vegetation_beachgrass_dormant_leaf_00015',
#  'vegetation_beachgrass_dormant_leaf_00016',
#  'vegetation_beachgrass_dormant_leaf_00017',
#  'vegetation_beachgrass_dormant_leaf_00018',
#  'vegetation_beachgrass_dormant_leaf_00019',
#  'vegetation_beachgrass_dormant_leaf_300000',
#  'vegetation_beachgrass_dormant_leaf_300001',
#  'vegetation_beachgrass_dormant_leaf_300002',
#  'vegetation_beachgrass_dormant_leaf_300003',
#  'vegetation_beachgrass_dormant_leaf_300004',
#  'vegetation_beachgrass_dormant_leaf_300005',
#  'vegetation_beachgrass_dormant_leaf_300006',
#  'vegetation_beachgrass_dormant_leaf_300007',
#  'vegetation_beachgrass_dormant_leaf_300008',
#  'vegetation_beachgrass_dormant_leaf_300009',
#  'vegetation_beachgrass_dormant_leaf_300010',
#  'vegetation_beachgrass_dormant_leaf_300011',
#  'vegetation_beachgrass_dormant_leaf_300012',
#  'vegetation_beachgrass_dormant_leaf_300013',
#  'vegetation_beachgrass_dormant_leaf_300014',
#  'vegetation_beachgrass_dormant_leaf_300015',
#  'vegetation_beachgrass_dormant_leaf_300016',
#  'vegetation_beachgrass_dormant_leaf_300017',
#  'vegetation_beachgrass_dormant_leaf_300018',
#  'vegetation_beachgrass_dormant_leaf_300019',
#  'vegetation_beachgrass_dormant_stalk_00000',
#  'vegetation_beachgrass_dormant_stalk_00001',
#  'vegetation_beachgrass_dormant_stalk_00002',
#  'vegetation_beachgrass_dormant_stalk_00003',
#  'vegetation_beachgrass_dormant_stalk_00004',
#  'vegetation_beachgrass_dormant_stalk_00005',
#  'vegetation_beachgrass_dormant_stalk_00006',
#  'vegetation_beachgrass_dormant_stalk_00007',
#  'vegetation_beachgrass_dormant_stalk_00008',
#  'vegetation_beachgrass_dormant_stalk_00009',
#  'vegetation_beachgrass_dormant_stalk_00010',
#  'vegetation_beachgrass_dormant_stalk_00011',
#  'vegetation_beachgrass_dormant_stalk_00012',
#  'vegetation_beachgrass_dormant_stalk_00013',
#  'vegetation_beachgrass_dormant_stalk_00014',
#  'vegetation_beachgrass_dormant_stalk_00015',
#  'vegetation_beachgrass_dormant_stalk_00016',
#  'vegetation_beachgrass_dormant_stalk_00017',
#  'vegetation_beachgrass_dormant_stalk_00018',
#  'vegetation_beachgrass_dormant_stalk_00019',
#  'vegetation_beachgrass_dormant_stalk_00020',
#  'vegetation_beachgrass_dormant_stalk_00021',
#  'vegetation_beachgrass_dormant_stalk_00022',
#  'vegetation_beachgrass_dormant_stalk_00023',
#  'vegetation_beachgrass_dormant_stalk_00024',
#  'vegetation_beachgrass_dormant_stalk_300000',
#  'vegetation_beachgrass_dormant_stalk_300001',
#  'vegetation_beachgrass_dormant_stalk_300002',
#  'vegetation_beachgrass_dormant_stalk_300003',
#  'vegetation_beachgrass_dormant_stalk_300004',
#  'vegetation_beachgrass_dormant_stalk_300005',
#  'vegetation_beachgrass_dormant_stalk_300006',
#  'vegetation_beachgrass_dormant_stalk_300007',
#  'vegetation_beachgrass_dormant_stalk_300008',
#  'vegetation_beachgrass_dormant_stalk_300009',
#  'vegetation_beachgrass_dormant_stalk_300010',
#  'vegetation_beachgrass_dormant_stalk_300011',
#  'vegetation_beachgrass_dormant_stalk_300012',
#  'vegetation_beachgrass_dormant_stalk_300013',
#  'vegetation_beachgrass_dormant_stalk_300014',
#  'vegetation_beachgrass_dormant_stalk_300015',
#  'vegetation_beachgrass_dormant_stalk_300016',
#  'vegetation_beachgrass_dormant_stalk_300017',
#  'vegetation_beachgrass_dormant_stalk_300018',
#  'vegetation_beachgrass_dormant_stalk_300019',
#  'vegetation_beachgrass_dormant_stalk_300020',
#  'vegetation_beachgrass_dormant_stalk_300021',
#  'vegetation_beachgrass_dormant_stalk_300022',
#  'vegetation_beachgrass_dormant_stalk_300023',
#  'vegetation_beachgrass_dormant_stalk_300024',
#  'vegetation_beachgrass_emergence_00000',
#  'vegetation_beachgrass_emergence_00001',
#  'vegetation_beachgrass_emergence_00002',
#  'vegetation_beachgrass_emergence_00003',
#  'vegetation_beachgrass_emergence_00004',
#  'vegetation_beachgrass_emergence_00005',
#  'vegetation_beachgrass_emergence_00006',
#  'vegetation_beachgrass_emergence_00007',
#  'vegetation_beachgrass_emergence_00008',
#  'vegetation_beachgrass_emergence_00009',
#  'vegetation_beachgrass_emergence_00010',
#  'vegetation_beachgrass_emergence_00011',
#  'vegetation_beachgrass_emergence_00012',
#  'vegetation_beachgrass_emergence_00013',
#  'vegetation_beachgrass_emergence_00014',
#  'vegetation_beachgrass_emergence_00015',
#  'vegetation_beachgrass_emergence_00016',
#  'vegetation_beachgrass_emergence_00017',
#  'vegetation_beachgrass_emergence_00018',
#  'vegetation_beachgrass_emergence_00019',
#  'vegetation_beachgrass_emergence_200000',
#  'vegetation_beachgrass_emergence_200001',
#  'vegetation_beachgrass_emergence_200002',
#  'vegetation_beachgrass_emergence_200003',
#  'vegetation_beachgrass_emergence_200004',
#  'vegetation_beachgrass_emergence_200005',
#  'vegetation_beachgrass_emergence_200006',
#  'vegetation_beachgrass_emergence_200007',
#  'vegetation_beachgrass_emergence_200008',
#  'vegetation_beachgrass_emergence_200009',
#  'vegetation_beachgrass_emergence_200010',
#  'vegetation_beachgrass_emergence_200011',
#  'vegetation_beachgrass_emergence_200012',
#  'vegetation_beachgrass_emergence_200013',
#  'vegetation_beachgrass_emergence_200014',
#  'vegetation_beachgrass_emergence_2_blade_200000',
#  'vegetation_beachgrass_emergence_2_blade_200001',
#  'vegetation_beachgrass_emergence_2_blade_200002',
#  'vegetation_beachgrass_emergence_2_blade_200003',
#  'vegetation_beachgrass_emergence_2_blade_200004',
#  'vegetation_beachgrass_emergence_2_senesced_200000',
#  'vegetation_beachgrass_emergence_2_senesced_200001',
#  'vegetation_beachgrass_emergence_2_senesced_200002',
#  'vegetation_beachgrass_emergence_2_senesced_200003',
#  'vegetation_beachgrass_emergence_2_senesced_200004',
#  'vegetation_beachgrass_emergence_2_stem_200000',
#  'vegetation_beachgrass_emergence_2_stem_200001',
#  'vegetation_beachgrass_emergence_2_stem_200002',
#  'vegetation_beachgrass_emergence_2_stem_200003',
#  'vegetation_beachgrass_emergence_2_stem_200004',
#  'vegetation_beachgrassss_mature_00000',
#  'vegetation_beachgrassss_mature_00001',
#  'vegetation_beachgrassss_mature_00002',
#  'vegetation_beachgrassss_mature_00003',
#  'vegetation_beachgrassss_mature_00004',
#  'vegetation_beachgrassss_mature_00005',
#  'vegetation_beachgrassss_mature_00006',
#  'vegetation_beachgrassss_mature_00007',
#  'vegetation_coastal-panic00000',
#  'vegetation_coastal-panic00001',
#  'vegetation_coastal-panic00002',
#  'vegetation_coastal-panic00003',
#  'vegetation_coastalpanicum_200000',
#  'vegetation_coastalpanicum_200001',
#  'vegetation_coastalpanicum_200002',
#  'vegetation_coastalpanicum_200003',
#  'vegetation_coolSeasonGrass_scenesed_00000',
#  'vegetation_coolSeasonGrass_scenesed_00001',
#  'vegetation_coolSeasonGrass_scenesed_00002',
#  'vegetation_coolSeasonGrass_scenesed_00003',
#  'vegetation_coolSeasonGrass_scenesed_00004',
#  'vegetation_foxgl_midseaseon00000',
#  'vegetation_foxgl_midseaseon00001',
#  'vegetation_foxgl_midseaseon00002',
#  'vegetation_foxgl_midseaseon00003',
#  'vegetation_foxgl_midseaseon00004',
#  'vegetation_foxgl_midseaseon00005',
#  'vegetation_foxgl_midseaseon00006',
#  'vegetation_foxgl_midseaseon00007',
#  'vegetation_foxgl_midseaseon00008',
#  'vegetation_foxgl_midseaseon00009',
#  'vegetation_foxgl_midseaseon00010',
#  'vegetation_foxgl_midseaseon00011',
#  'vegetation_foxgl_midseaseon00012',
#  'vegetation_foxgl_midseaseon00013',
#  'vegetation_foxgl_midseaseon00014',
#  'vegetation_foxgl_midseaseon00015',
#  'vegetation_foxgl_midseaseon00016',
#  'vegetation_foxgl_midseaseon00017',
#  'vegetation_foxgl_midseaseon00018',
#  'vegetation_foxgl_midseaseon00019',
#  'vegetation_foxgl_midseaseon00020',
#  'vegetation_foxgl_midseaseon00021',
#  'vegetation_foxgl_midseaseon00022',
#  'vegetation_foxgl_midseaseon00023',
#  'vegetation_foxgl_midseaseon00024',
#  'vegetation_foxgl_midseaseon00025',
#  'vegetation_foxgl_midseaseon00026',
#  'vegetation_foxgl_midseaseon00027',
#  'vegetation_foxgl_midseaseon00028',
#  'vegetation_foxgl_midseaseon00029',
#  'vegetation_milkweed_midseason_00000',
#  'vegetation_milkweed_midseason_00001',
#  'vegetation_milkweed_midseason_00002',
#  'vegetation_milkweed_midseason_00003',
#  'vegetation_milkweed_midseason_00004',
#  'vegetation_milkweed_midseason_00005',
#  'vegetation_partridge-pea00000',
#  'vegetation_partridge-pea00001',
#  'vegetation_partridge-pea00002',
#  'vegetation_partridge-pea00003',
#  'vegetation_partridgePea_00000',
#  'vegetation_partridgePea_00001',
#  'vegetation_partridgePea_00002',
#  'vegetation_partridgePea_00003',
#  'vegetation_partridgePea_flowering_00000',
#  'vegetation_partridgePea_flowering_00001',
#  'vegetation_partridgePea_flowering_00002',
#  'vegetation_partridgePea_flowering_00003',
#  'vegetation_partridgePea_flowering_00004',
#  'vegetation_partridgePea_flowering_00005',
#  'vegetation_partridgePea_flowering_00006',
#  'vegetation_partridgePea_flowering_00007',
#  'vegetation_partridgePea_flowering_00008',
#  'vegetation_pasturegrassFL_00000',
#  'vegetation_pasturegrassFL_00001',
#  'vegetation_pasturegrassFL_00002',
#  'vegetation_pasturegrassFL_00003',
#  'vegetation_pasturegrassFL_00004',
#  'vegetation_pasturegrassFL_00005',
#  'vegetation_pasturegrassFL_00006',
#  'vegetation_pasturegrassFL_00007',
#  'vegetation_pasturegrassFL_00008',
#  'vegetation_pasturegrassFL_00009',
#  'vegetation_pasturegrassFL_100000',
#  'vegetation_pasturegrassFL_100001',
#  'vegetation_pasturegrassFL_100002',
#  'vegetation_pasturegrassFL_100003',
#  'vegetation_pasturegrassFL_100004',
#  'vegetation_pasturegrassFL_100005',
#  'vegetation_pasturegrassFL_100006',
#  'vegetation_pasturegrassFL_100007',
#  'vegetation_pasturegrassFL_100008',
#  'vegetation_pasturegrassFL_100009',
#  'vegetation_pasturegrassPF_00000',
#  'vegetation_pasturegrassPF_00001',
#  'vegetation_pasturegrassPF_00002',
#  'vegetation_pasturegrassPF_00003',
#  'vegetation_pasturegrassPF_00004',
#  'vegetation_pasturegrassPF_100000',
#  'vegetation_pasturegrassPF_100001',
#  'vegetation_pasturegrassPF_100002',
#  'vegetation_pasturegrassPF_100003',
#  'vegetation_pasturegrassPF_100004',
#  'vegetation_pasturegrass_00000',
#  'vegetation_pasturegrass_00001',
#  'vegetation_pasturegrass_00002',
#  'vegetation_pasturegrass_00003',
#  'vegetation_pasturegrass_00004',
#  'vegetation_pasturegrass_00005',
#  'vegetation_pasturegrass_00006',
#  'vegetation_pasturegrass_00007',
#  'vegetation_pasturegrass_00008',
#  'vegetation_pasturegrass_00009',
#  'vegetation_pasturegrass_100000',
#  'vegetation_pasturegrass_100001',
#  'vegetation_pasturegrass_100002',
#  'vegetation_pasturegrass_100003',
#  'vegetation_pasturegrass_100004',
#  'vegetation_pasturegrass_100005',
#  'vegetation_pasturegrass_100006',
#  'vegetation_pasturegrass_100007',
#  'vegetation_pasturegrass_100008',
#  'vegetation_pasturegrass_100009',
#  'vegetation_soy_midseaseon00000',
#  'vegetation_soy_midseaseon00001',
#  'vegetation_soy_midseaseon00002',
#  'vegetation_soy_midseaseon00003',
#  'vegetation_soy_midseaseon00004',
#  'vegetation_soy_midseaseon00005',
#  'vegetation_soy_midseaseon00006',
#  'vegetation_soy_midseaseon00007',
#  'vegetation_soy_midseaseon00008',
#  'vegetation_soy_midseaseon00009',
#  'vegetation_soy_midseaseon00010',
#  'vegetation_soy_midseaseon00011',
#  'vegetation_soy_midseaseon00012',
#  'vegetation_soy_midseaseon00013',
#  'vegetation_soy_midseaseon00014',
#  'vegetation_soy_midseaseon00015',
#  'vegetation_soy_midseaseon00016',
#  'vegetation_soy_midseaseon00017',
#  'vegetation_soy_midseaseon00018',
#  'vegetation_soy_midseaseon00019',
#  'vegetation_soy_midseaseon00020',
#  'vegetation_soy_midseaseon00021',
#  'vegetation_soy_midseaseon00022',
#  'vegetation_soy_midseaseon00023',
#  'vegetation_soy_midseaseon00024',
#  'vegetation_soybean_leaf00000',
#  'vegetation_soybean_leaf00001',
#  'vegetation_soybean_leaf00002',
#  'vegetation_soybean_leaf00003',
#  'vegetation_soybean_leaf00004',
#  'vegetation_soybean_leaf00005',
#  'vegetation_soybean_leaf00006',
#  'vegetation_soybean_leaf00007',
#  'vegetation_soybean_leaf00008',
#  'vegetation_soybean_leaf00009',
#  'vegetation_soybean_leaf00010',
#  'vegetation_soybean_leaf_00000',
#  'vegetation_soybean_leaf_00001',
#  'vegetation_soybean_leaf_00002',
#  'vegetation_soybean_leaf_00003',
#  'vegetation_soybean_leaf_00004',
#  'vegetation_soybean_leaf_00005',
#  'vegetation_soybean_leaf_00006',
#  'vegetation_soybean_leaf_00007',
#  'vegetation_soybean_leaf_00008',
#  'vegetation_soybean_leaf_00009',
#  'vegetation_soybean_leaf_00010',
#  'vegetation_timothy_leaf00000',
#  'vegetation_timothy_leaf00001',
#  'vegetation_timothy_leaf00002',
#  'vegetation_timothy_leaf_00000',
#  'vegetation_timothy_leaf_00001',
#  'vegetation_timothy_leaf_00002',
#  'vegetation_timothy_seedhead00000',
#  'vegetation_timothy_seedhead00001',
#  'vegetation_timothy_seedhead00002',
#  'vegetation_timothy_seedhead00003',
#  'vegetation_timothy_seedhead_00000',
#  'vegetation_timothy_seedhead_00001',
#  'vegetation_timothy_seedhead_00002',
#  'vegetation_timothy_seedhead_00003']

# %% [markdown]
# # Check Data Scale

# %%
plt.figure(figsize=(12,4))
plt.plot(wl_im, imArr[100,100,:].flatten(), label='Image Spectrum')
plt.plot(wl_im, imArr[172,233,:].flatten(), label='Very Bright Image Spectrum')
plt.plot(wl_lib, spectra[5,:].flatten(), label='Lib Spectrum')
plt.grid()
plt.legend()

# %% [markdown]
# ### Observation: The image spectra and library spectra appear to be approximately on the same scale. It looks like 100% reflectance corresponds to about 6000.  This value doesn't matter much as long as they are on similar scales.

# %% [markdown]
# # Check wavelengths

# %%
print(f'Number of image wavelengths: {len(wl_im)}.')
print(f'Number of library wavelengths: {len(wl_lib)}.')
print('')
print(f'First 10 image wavelengths: {wl_im[:10]}.')
print('')
print(f'First 10 library wavelengths: {wl_lib[:10]}.')
# Out:
# Number of image wavelengths: 343.
# Number of library wavelengths: 2151.
#
# First 10 image wavelengths: [399.096008 400.854004 402.612    404.369995 406.127991 407.885986
#  409.644012 411.403015 413.161011 414.919006].
#
# First 10 library wavelengths: [350. 351. 352. 353. 354. 355. 356. 357. 358. 359.].

# %% [markdown]
# ### Observation: The library spectrum has many more wavelengths than the image.  Also, there is about 14nm between succsive image wavelength and about 1nm between library wavelengths.

# %%
plt.figure(figsize=(8,4))
plt.title('An image spectrum and a library spectrum showing band locations with markers.')
plt.plot(wl_im, imArr[100,100,:].flatten(), marker='.', label='Image Spectrum')
plt.plot(wl_lib, spectra[5,:].flatten(), marker='.', label='Orig Lib Spectrum')
plt.grid()
plt.legend()

# %% [markdown]
# ### Resampling the library wavelength to match the image.

# %%
# Create a BandResampler, which is a function that resamples spectra from one source to match a different source.
# See: https://www.spectralpython.net/class_func_ref.html?highlight=resampling#spectral.algorithms.resampling.BandResampler
# Inputs: the first input is the wavelengths for the spectra that you are going to resample, the second input is the wavelevngths that you want to resample to.
resampler = spectral.BandResampler(wl_lib, wl_im)
spectra_resampled = resampler(lib.spectra.T).T

print(f'The shape of the spectral library is {spectra_resampled.shape}.')
print(f'({spectra_resampled.shape[0]} spectra with {spectra_resampled.shape[1]} bands.)')
# Out:
# The shape of the spectral library is (938, 343).
# (938 spectra with 343 bands.)

# %%
plt.figure(figsize=(12,5))
plt.title('An image spectrum with library spectra before and after resampling, showing band locations with markers.')
plt.plot(wl_im, imArr[100,100,:].flatten(), marker='.', label='Image Spectrum')
plt.plot(wl_lib, spectra[5,:].flatten(), marker='.', label='Orig Lib Spectrum')
plt.plot(wl_im, spectra_resampled[5,:].flatten(), marker='.', label='Resampled Lib Spectrum')
plt.xlabel('Wavelength (nm)')
plt.grid()
plt.legend();

# %%
# now that the library is resampled, let's use simple names.
spec = spectra_resampled # spectra from the library, after resampling
wl = wl_im # the wavelengths for the image and the resampled library

# %% [markdown]
# # Matched Filter Target Detection
# 1. Compute the mean and covariance.
# 2. Whiten the image and target spectra.
# 3. Compute the Matched Filter score for each pixel:
# $$
#     MF(x) = \frac{\r{x}^T \r{t}}{\r{t}^T \r{t}}
# $$
# where $\r{x}$ is a whitened pixel spectrum and $\r{t}$ is the whitened target spectrum.
#
# We showed in class that computing $MF(x)$ is derived by assuming we have a non-target class (or background class) and a target class whose distributions are given by
# $$
# x \sim \mathcal{N}(\mu,\Sigma), x \sim \mathcal{N}t,\Sigma)
# $$
# where $\mu$ and $\Sigma$ are computed from the image and $t$ is the target spectrum.  The $MF(x)$ score is then equivalent to the log-likelihood ratio test using these destributions  Specificially, that
# $$
# MF(x) = A \times \ln\left(\frac{l(x;\mu,\Sigma)}{l(x;t,\Sigma)}\right) + B
# $$
# for some constants $A$ and $B$, and where $l(x;\mu,\Sigma)$ is the multivaraite normal distribution likelihood function
# $$
# l(x;\mu,\Sigma)= \frac{1}{(2\pi)^{k/2}{|\Sigma|}^{-1}}\exp\left(-\frac{1}{2} (x-\mu)^T\Sigma^{-1}(x-\mu)\right).
# $$

# %% [markdown]
# [the above ratio should be flipped, I think]

# %% [markdown]
# ## 1. Compute the mean and covariance.

# %%
C = np.cov(imList, rowvar=False) # each pixel is an observation, and each band is a variable. The default behavior of np.cov() is rowvar=True, which assumes rows are variables. 
m = np.mean(imList, axis=0)

# %%
C.shape
# Out:
# (126, 126)

# %% [markdown]
# ## 2. Whiten the Image

# %%
# Compute the eigenvectors, eigenvalues, and whitening matrix
evals,evecs = np.linalg.eig(C)
# truncate the small eigenvalues to stablize the inverse, if needed
#evals[evals<tol] = tol
DiagMatrix = np.diag(evals**(-1/2)) # dividing by the sqrt of each eval scales (normalizes) the spread (variance) of the data in the direction of each evec to 1
W = np.matmul(evecs,DiagMatrix)
ImListDemean = imList - m

#The goal of whitening is to transform the data so that it has unit variance along all dimensions and the dimensions are uncorrelated. We achieve this by:
#Rotating the data: Multiplying the data by the eigenvector matrix (evecs) rotates the data so that the principal components align with the coordinate axes.
#Scaling the data: After rotation, each dimension's variance corresponds to an eigenvalue. To get unit variance, we need to scale each dimension by the inverse square root of the corresponding eigenvalue.
# This is why we compute evals**(-1/2). Dividing by the square root of the eigenvalue scales the variance to 1.
# Recall that to calculate correlation, we normalize the covariance by dividing by the stdev (covariance divided by the product of the standard deviations of the two variables involved)

print(W.shape)
print(ImListDemean.shape)

#WimList = np.matmul(W.T, ImListDemean.T).T
WimList = np.matmul(ImListDemean, W)

#print(WimList.shape, WimList[:10])
#print(WimList2.shape, WimList2[:10])
# Out:
# (126, 126)
# (224000, 126)

# %% [markdown]
# ## 3. Whiten the spectral library

# %%
SpecDemean = spec - m
#Wspec = np.matmul(W.T, SpecDemean.T).T
Wspec = np.matmul(SpecDemean, W)

# %% [markdown]
# ## 4. Compute the values for MF efficiently.

# %%
print(f'Whitened pixel array shape: {WimList.shape}.')
print(f'Whitened target library array shape: {Wspec.shape}.')
ntargets = Wspec.shape[0]
# Out:
# Whitened pixel array shape: (224000, 126).
# Whitened target library array shape: (18, 126).

# %% [markdown]
# We will compute the value of $MF(x)$ for every pixel and every target spectra efficiently using matrix multiplication.  We compute the numerator (of shape (nPix)x(nTargets)=(224,000)x(18)) and denominator (of shape (nTargets)=(18)) seperately, and then divide them.  The matrix multiplication showing the spectra is shown below.
#
# $$
# \textrm{Numerator} =
# \left[
#   \begin{array}{ccc}
#     {\rule[.5ex]{2.5ex}{0.5pt}} & \r{x}^{T}_{1} & {\rule[.5ex]{2.5ex}{0.5pt}} \\
#     {\rule[.5ex]{2.5ex}{0.5pt}} & \r{x}^{T}_{2} & {\rule[.5ex]{2.5ex}{0.5pt}} \\
#     {\rule[.5ex]{2.5ex}{0.5pt}} & \vdots & {\rule[.5ex]{2.5ex}{0.5pt}} \\
#     {\rule[.5ex]{2.5ex}{0.5pt}} & \r{x}^{T}_{224,000} & {\rule[.5ex]{2.5ex}{0.5pt}} \\
#   \end{array}
# \right]
# \left[
#   \begin{array}{ccc}
#     {\rule[-1ex]{0.5pt}{2.5ex}} & {\rule[-1ex]{0.5pt}{2.5ex}} & {\rule[-1ex]{0.5pt}{2.5ex}} & {\rule[-1ex]{0.5pt}{2.5ex}} \\
#     {\r{t}_1} & {\r{t}_2} & \cdots &{\r{t}_{18}} \\
#     {\rule[-1ex]{0.5pt}{2.5ex}} & {\rule[-1ex]{0.5pt}{2.5ex}} & {\rule[-1ex]{0.5pt}{2.5ex}} & {\rule[-1ex]{0.5pt}{2.5ex}} \\
#   \end{array}
# \right]
# =
# \left[
#   \begin{array}{ccc}
#     \r{x}^{T}_{1}\r{t}_1 & \dots  & \r{x}^{T}_{1}\r{t}_{18}\\
#     \vdots & \ddots & \vdots\\
#     \r{x}^{T}_{224,000}\r{t}_1 & \dots  & \r{x}^{T}_{224,000}\r{t}_{18}
#   \end{array}
# \right]
# $$
#
#
# $$
# \textrm{Denominator} =
# \left[
#   \begin{array}{ccc}
#     {\r{t}_{1}}^2 & \cdots  & {\r{t}_{18}}^2\\
#   \end{array}
# \right]
# $$
#
# Then $MF=\frac{Numerator}{Denominator}$ where the division is done by broadcasting the divsion of each row in the Numerator byt the Denomenator.

# %%
# The computation is now simple
numerator = np.matmul(WimList,Wspec.T) # We need X dot T / T dot T, which is X'T / T'T; since both vars are row vectors (but the formula assumes column vectors), we need to take the transpose of T to get the proper form
x_dot_t = numerator
print(numerator.shape)
denom = np.sum(Wspec**2, axis=1)
t_dot_t = denom
print(denom.shape)
MF = np.squeeze(numerator / denom)

print(MF.shape)

# Lets reshape this result so we can compare it to the image
MF = np.reshape(MF, (im.nrows, im.ncols, ntargets))
# Out:
# (224000, 18)
# (18,)
# (224000, 18)

# %%
# Computation for ACE

denom1 = np.sqrt(np.sum(WimList**2, axis=1, keepdims=True))
hyp = denom1
print(denom1.shape)
denom2 = np.sqrt(t_dot_t)
sqrt_t_dot_t = denom2
print(denom2.shape)
denom = denom1 * denom2
print(denom.shape)

ACE = numerator / denom

print(ACE.shape)

ACE = np.reshape(ACE, (im.nrows, im.ncols, ntargets))

print(ACE.shape)
# Out:
# (224000, 1)
# (18,)
# (224000, 18)
# (224000, 18)
# (280, 800, 18)

# %%
# explore the image in our hyperspectral image viewer
from hsiViewer import hsi_viewer_layers as hvl
layers = {}
for i in range(ntargets):
    layers[names[i]] = MF[:,:,i].squeeze()
hvl.viewer(im, layers=layers)

# %%
# the detection planes will look better if we only show values > 0
from hsiViewer import hsi_viewer_layers as hvl
layers = {}
for i in range(ntargets):
    MF_layer = MF[:,:,i].squeeze()
    MF_layer[MF[:,:,i].squeeze()<0] = 0
    layers[names[i]] = MF_layer
hvl.viewer(im, layers=layers)

# %%
# We can view the results of the matched filter detections for all pixels in the image for a given target, called a 'detection plane' as:
idx = 17
plt.figure(figsize=(8,7))

plt.subplot(2, 1, 1)  
plt.imshow(MF[:,:,idx], cmap='jet')
plt.title(f'MF Detection Plane for {names[0]}')

plt.subplot(2, 1, 2)  
plt.hist(MF[:,:,idx].flatten(), bins=1000);
plt.title(f'Histogram MF Detection Scores for {names[idx]}')
plt.grid(True)
plt.xlabel('MF Score');
plt.tight_layout()

# %%
# We can view the results of the matched filter detections for all pixels in the image for a given target, called a 'detection plane' as:
idx = 17
MF_threshold = MF[:,:,idx].squeeze()
MF_threshold[MF_threshold<0] = 0
plt.figure(figsize=(8,7))

plt.subplot(2, 1, 1)  
plt.imshow(MF_threshold, cmap='jet')
plt.title(f'MF Detection Plane for {names[0]}')

plt.subplot(2, 1, 2)  
plt.hist((MF_threshold[MF_threshold>0]).flatten(), bins=1000);
plt.title(f'Histogram MF Detection Scores Above Zero for {names[idx]}')
plt.grid(True)
plt.xlabel('MF Score');
plt.tight_layout()

# %%
#Ace
# We can view the results of the ace detections for all pixels in the image for a given target, called a 'detection plane' as:
idx = 17
ACE_threshold = ACE[:,:,idx].squeeze()
ACE_threshold[ACE_threshold<0] = 0
plt.figure(figsize=(8,7))

plt.subplot(2, 1, 1)  
plt.imshow(ACE_threshold, cmap='jet')
plt.title(f'ACE Detection Plane for {names[0]}')

plt.subplot(2, 1, 2)  
plt.hist((ACE_threshold[ACE_threshold>0]).flatten(), bins=1000);
plt.title(f'Histogram ACE Detection Scores Above Zero for {names[idx]}')
plt.grid(True)
plt.xlabel('ACE Score');
plt.tight_layout()

# %%
# We can view the results of the matched filter detections for all pixels in the image for a given target, called a 'detection plane' as:
import copy
idx = 17
MF_threshold = MF[:,:,idx].squeeze()
m = np.mean(MF_threshold)
s = np.std(MF_threshold)
MF_threshold[MF_threshold<0] = 0


plt.figure(figsize=(8,7))

plt.subplot(2, 1, 2)  
plt.hist((MF_threshold[MF_threshold>0]).flatten(), bins=1000);
plt.title(f'Histogram MF Detection Scores Above Zero for {names[0]}')
plt.axvline(m+2*s, color='orange', label=f'2 Standard Deviations, MF={(m+2*s):.3f}')
plt.axvline(m+4*s, color='green', label=f'4 Standard Deviations, MF={(m+4*s):.3f}')
plt.axvline(m+6*s, color='red', label=f'6 Standard Deviations, MF={(m+6*s):.3f}')
plt.legend()
plt.grid(True)
plt.xlabel('MF Score');
plt.tight_layout()

# Create an RGB image that is gray at locations without detections, 
# and red on pixels with above 6-standard deviation detection scores.
detections = np.where(MF_threshold>m+6*s)
# get the image band at 750nm, and stretch the values to be in 0-1
band_750 = np.argmin(np.abs(wl-750)) # get the index for the band closest to wl=750
image_detections_singleband = imArr[:,:,band_750].squeeze()
image_detections_singleband = image_detections_singleband - np.min(image_detections_singleband)
image_detections_singleband = image_detections_singleband/np.max(image_detections_singleband)
# build a color RGB image from this one band, making the detection locations red
image_detections_red = copy.deepcopy(image_detections_singleband) # copy here makes a copy of the array, so we don't alter the original array
image_detections_green = copy.deepcopy(image_detections_singleband)
image_detections_blue = copy.deepcopy(image_detections_singleband)
image_detections_red[detections] = 0.99
image_detections_green[detections] = 0
image_detections_blue[detections] = 0
image_detections_RGB = np.zeros((im.nrows,im.ncols,3))
image_detections_RGB[:,:,0] = image_detections_red
image_detections_RGB[:,:,1] = image_detections_green
image_detections_RGB[:,:,2] = image_detections_blue


plt.subplot(2, 1, 1)  
plt.imshow(image_detections_RGB)
plt.title(f'MF Detections for {names[idx]} Scoring above 6 $\sigma$');
# Out:
# <>:46: SyntaxWarning: invalid escape sequence '\s'
# <>:46: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_669/2299486111.py:46: SyntaxWarning: invalid escape sequence '\s'
#   plt.title(f'MF Detections for {names[idx]} Scoring above 6 $\sigma$');

# %%
# ACE
# We can view the results of the matched filter detections for all pixels in the image for a given target, called a 'detection plane' as:
import copy
idx = 17
ACE_threshold = ACE[:,:,idx].squeeze()
m = np.mean(ACE_threshold)
s = np.std(ACE_threshold)
ACE_threshold[ACE_threshold<0] = 0


plt.figure(figsize=(8,7))

plt.subplot(2, 1, 2)  
plt.hist((ACE_threshold[ACE_threshold>0]).flatten(), bins=1000);
plt.title(f'Histogram ACE Detection Scores Above Zero for {names[0]}')
plt.axvline(m+2*s, color='orange', label=f'2 Standard Deviations, ACE={(m+2*s):.3f}')
plt.axvline(m+4*s, color='green', label=f'4 Standard Deviations, ACE={(m+4*s):.3f}')
plt.axvline(m+6*s, color='red', label=f'6 Standard Deviations, ACE={(m+6*s):.3f}')
plt.legend()
plt.grid(True)
plt.xlabel('ACE Score');
plt.tight_layout()

# Create an RGB image that is gray at locations without detections, 
# and red on pixels with above 6-standard deviation detection scores.
detections = np.where(ACE_threshold>m+6*s)
# get the image band at 750nm, and stretch the values to be in 0-1
band_750 = np.argmin(np.abs(wl-750)) # get the index for the band closest to wl=750
image_detections_singleband = imArr[:,:,band_750].squeeze()
image_detections_singleband = image_detections_singleband - np.min(image_detections_singleband)
image_detections_singleband = image_detections_singleband/np.max(image_detections_singleband)
# build a color RGB image from this one band, making the detection locations red
image_detections_red = copy.deepcopy(image_detections_singleband) # copy here makes a copy of the array, so we don't alter the original array
image_detections_green = copy.deepcopy(image_detections_singleband)
image_detections_blue = copy.deepcopy(image_detections_singleband)
image_detections_red[detections] = 0.99
image_detections_green[detections] = 0
image_detections_blue[detections] = 0
image_detections_RGB = np.zeros((im.nrows,im.ncols,3))
image_detections_RGB[:,:,0] = image_detections_red
image_detections_RGB[:,:,1] = image_detections_green
image_detections_RGB[:,:,2] = image_detections_blue


plt.subplot(2, 1, 1)  
plt.imshow(image_detections_RGB)
plt.title(f'ACE Detections for {names[idx]} Scoring above 6 $\sigma$');
# Out:
# <>:47: SyntaxWarning: invalid escape sequence '\s'
# <>:47: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_669/1888879068.py:47: SyntaxWarning: invalid escape sequence '\s'
#   plt.title(f'ACE Detections for {names[idx]} Scoring above 6 $\sigma$');

# %% [markdown]
# # Create ROI Ground Truth

# %%
from hsiViewer import hsi_viewer_ROI as hvr
importlib.reload(hvr)
#hvr.viewer(im, stretch=[2,98], rotate=True)
# Out:
# <module 'hsiViewer.hsi_viewer_ROI' from '/workspaces/Machine-Learning-for-Spectral-Imaging/Book_Modules/hsiViewer/hsi_viewer_ROI.py'>

# %%
import pickle
fname = '/workspaces/Machine-Learning-for-Spectral-Imaging/Final Project Materials/UPWINS Baccharis Halimifolia.pkl'
with open(fname, 'rb') as f:
    roiData = pickle.load(f)

# %%
roiData.names
# Out:
# ['Baccharis Halimifolia',
#  'Flag',
#  'Ribbon',
#  'Background Healthy',
#  'Background Scenesced']

# %%
roiData.colors
# Out:
# {'Baccharis Halimifolia': '#fa3232',
#  'Flag': '#fdec02',
#  'Ribbon': '#ff43ff',
#  'Background Healthy': '#108304',
#  'Background Scenesced': '#baae80'}

# %%
roiData.colors['F1']

# %%
roiData.masks
# Out:
# {'Baccharis Halimifolia': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]),
#  'Flag': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]),
#  'Ribbon': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]),
#  'Background Healthy': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]),
#  'Background Scenesced': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]])}

# %%
plt.imshow(roiData.masks['F1'])

# %%
roiData.df
# Out:
#                       Name    Color  Pixel_x  Pixel_y  399.096008  400.854004  \
# 0    Baccharis Halimifolia  #fa3232      175      155      0.0282      0.0368
# 1    Baccharis Halimifolia  #fa3232      174      156      0.0282      0.0368
# 2    Baccharis Halimifolia  #fa3232      175      156      0.0334      0.0369
# 3    Baccharis Halimifolia  #fa3232      173      157      0.0282      0.0368
# 4    Baccharis Halimifolia  #fa3232      174      157      0.0332      0.0369
# ..                     ...      ...      ...      ...         ...         ...
# 249   Background Scenesced  #baae80      108      172      0.0547      0.0529
# 250   Background Scenesced  #baae80      104      173      0.0451      0.0459
# 251   Background Scenesced  #baae80      105      173      0.0460      0.0515
# 252   Background Scenesced  #baae80      106      173      0.0425      0.0466
# 253   Background Scenesced  #baae80      105      174      0.0406      0.0417
#
#      402.612  404.369995  406.127991  407.885986  ...  984.531006  986.289001  \
# 0     0.0366      0.0344      0.0230      0.0356  ...      0.4109      0.3889
# 1     0.0366      0.0344      0.0230      0.0356  ...      0.4109      0.3889
# 2     0.0309      0.0318      0.0287      0.0324  ...      0.4090      0.3906
# 3     0.0366      0.0344      0.0230      0.0356  ...      0.4109      0.3889
# 4     0.0311      0.0319      0.0285      0.0325  ...      0.4091      0.3905
# ..       ...         ...         ...         ...  ...         ...         ...
# 249   0.0493      0.0510      0.0494      0.0515  ...      0.3388      0.3305
# 250   0.0377      0.0331      0.0342      0.0394  ...      0.3737      0.2927
# 251   0.0426      0.0450      0.0347      0.0380  ...      0.3536      0.3609
# 252   0.0452      0.0468      0.0481      0.0403  ...      0.2934      0.3556
# 253   0.0425      0.0402      0.0379      0.0365  ...      0.3062      0.3493
#
#      988.047974  989.80603  991.564026  993.322021  995.080017  996.838013  \
# 0        0.4285     0.3314      0.3840      0.3716      0.3766      0.3416
# 1        0.4285     0.3314      0.3840      0.3716      0.3766      0.3416
# 2        0.4206     0.3356      0.3441      0.3810      0.3301      0.3485
# 3        0.4285     0.3314      0.3840      0.3716      0.3766      0.3416
# 4        0.4209     0.3354      0.3456      0.3806      0.3319      0.3482
# ..          ...        ...         ...         ...         ...         ...
# 249      0.3511     0.3505      0.3243      0.3076      0.3674      0.3502
# 250      0.3801     0.3776      0.3098      0.4160      0.2905      0.3880
# 251      0.3262     0.2731      0.3314      0.3233      0.3458      0.3880
# 252      0.2697     0.3226      0.3806      0.3279      0.3358      0.3361
# 253      0.3532     0.3006      0.3403      0.3349      0.2567      0.3691
#
#      998.596008  1000.349976
# 0        0.3801       0.3947
# 1        0.3801       0.3947
# 2        0.3527       0.3558
# 3        0.3801       0.3947
# 4        0.3538       0.3573
# ..          ...          ...
# 249      0.3996       0.3676
# 250      0.3429       0.4168
# 251      0.3494       0.4168
# 252      0.3974       0.2698
# 253      0.2475       0.3204
#
# [1410 rows x 347 columns]

# %% [markdown]
# # Observing the pixel and library spectra, before and after whitening.

# %%
# reshape the whitened image spectra to iamge shape
WimArr = np.reshape(WimList, (im.nrows,im.ncols,im.nbands))
# select the whitened pixel for the pixel containing the red cotton fabric target
F1_idx = [137,503]
pix_F1_Gr = imArr[F1_idx[0], F1_idx[1], :].flatten()
# select the whitened pixel for pure grass
Grass_idx = [139,507]
pix_Gr = imArr[Grass_idx[0], Grass_idx[1], :].flatten()
# select the whitened spectrum from the library for fabric F1
lib_F1 = spec[17,:]

# Plot all three whitened spectra together.  Observe that:
# 1. The grass has small values because it represents a common material (high likelihood).
# 2. The pixel with grass and the red fabric has larger values.
# 3. The library spectrum has very large values because it is very different from materials in the image.
plt.figure(figsize=(15,4))
plt.plot(pix_F1_Gr, label='F1 Pixel Spectrum')
plt.plot(pix_Gr, label='Grass Pixel Spectrum')
plt.plot(lib_F1, label='F1 Library Spectrum')
plt.minorticks_on()
plt.grid(True, which='major', c='k')
plt.grid(True, which='minor', linewidth=0.25)
plt.title('Two pixel spectra and a library spectrum, after whitening.')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Reflectance')
plt.legend();

# %%
print(pix_F1_Gr.shape)
# Out:
# (126,)

# %%
# Compute correlations:
pix_F1_Gr_normalized = (pix_F1_Gr-np.mean(pix_F1_Gr))/np.std(pix_F1_Gr)
pix_Gr_normalized = (pix_Gr-np.mean(pix_Gr))/np.std(pix_Gr)
lib_F1_normalized = (lib_F1-np.mean(lib_F1))/np.std(lib_F1)
print(f'pix_Gr to pix_F1 correlation {(1/len(wl))*np.dot(pix_F1_Gr_normalized,pix_Gr_normalized):.3f}')
print(f'pix_Gr to lib_F1 correlation {(1/len(wl))*np.dot(pix_Gr_normalized,lib_F1_normalized):.3f}')
print(f'pix_F1_Gr to lib_F1 correlation {(1/len(wl))*np.dot(pix_F1_Gr_normalized,lib_F1_normalized):.3f}')
# Out:
# pix_Gr to pix_F1 correlation 0.992
# pix_Gr to lib_F1 correlation 0.702
# pix_F1_Gr to lib_F1 correlation 0.764

# %%
# reshape the whitened image spectra to iamge shape
WimArr = np.reshape(WimList, (im.nrows,im.ncols,im.nbands))
# select the whitened pixel for the pixel containing the red cotton fabric target
F1_idx = [137,503]
WimSpec_F1 = WimArr[F1_idx[0], F1_idx[1], :].flatten()
# select the whitened pixel for pure grass
Grass_idx = [139,507]
WimSpec_Gr = WimArr[Grass_idx[0], Grass_idx[1], :].flatten()
# select the whitened spectrum from the library for fabric F1
Wspec_F1 = Wspec[17,:]

# Plot all three whitened spectra together.  Observe that:
# 1. The grass has small values because it represents a common material (high likelihood).
# 2. The pixel with grass and the red fabric has larger values.
# 3. The library spectrum has very large values because it is very different from materials in the image.
plt.figure(figsize=(15,4))
plt.plot(WimSpec_F1, label='F1 Image Spectrum')
plt.plot(WimSpec_Gr, label='Grass Image Spectrum')
plt.plot(Wspec_F1, label='F1 Library Spectrum')
plt.minorticks_on()
plt.grid(True, which='major', c='k')
plt.grid(True, which='minor', linewidth=0.25)
plt.title('Two pixel spectra and a library spectrum, after whitening.')
plt.xlabel('Band Number')
plt.ylabel('Standard Deviations Per-Band')
plt.legend();

# %%
# Recreate the plot, but normalizing the whitened spectra so we can compare the and look for correlation
plt.figure(figsize=(15,4))
plt.plot(WimSpec_F1/np.mean(WimSpec_F1), label='F1 Image Spectrum')
plt.plot(WimSpec_Gr/np.mean(WimSpec_Gr), label='Grass Image Spectrum', alpha=0.3)
plt.plot(Wspec_F1/np.mean(Wspec_F1), label='F1 Library Spectrum')
plt.minorticks_on()
plt.grid(True, which='major', c='k')
plt.grid(True, which='minor', linewidth=0.25)
plt.title('Two pixel spectra and a library spectrum, after whitening and normalizing.')
plt.xlabel('Band Number')
plt.ylabel('Standard Deviations Per-Band')
plt.legend();

# %%
# Compute correlations:
Wpix_F1_Gr_normalized = (WimSpec_F1-np.mean(WimSpec_F1))/np.std(WimSpec_F1)
Wpix_Gr_normalized = (WimSpec_Gr-np.mean(WimSpec_Gr))/np.std(WimSpec_Gr)
Wlib_F1_normalized = (Wspec_F1-np.mean(Wspec_F1))/np.std(Wspec_F1)
print(f'pix_Gr to pix_F1 correlation {(1/len(wl))*np.dot(Wpix_F1_Gr_normalized,Wpix_Gr_normalized):.3f}')
print(f'pix_Gr to lib_F1 correlation {(1/len(wl))*np.dot(Wpix_Gr_normalized,Wlib_F1_normalized):.3f}')
print(f'pix_F1_Gr to lib_F1 correlation {(1/len(wl))*np.dot(Wpix_F1_Gr_normalized,Wlib_F1_normalized):.3f}')
# Out:
# pix_Gr to pix_F1 correlation 0.085
# pix_Gr to lib_F1 correlation -0.002
# pix_F1_Gr to lib_F1 correlation 0.820

# %% [markdown]
# ## Observations:
#
# 1. The image pixel with F1 and the F1 target spectra are very correlated after whitening.
# 2. Whitening de-emphaises the contribution of common (high-likelihood) materials, and emphasizes the contribution of rare (low-likelihood, anomalous) materials.

# %% [markdown]
# ## Visualizing the effects of whitening:

# %%
plt.figure(figsize=(16,8))

plt.subplot(1, 2, 1)  
plt.title('Scatterplot of Original Data')
plt.scatter(imList[:,30],imList[:,80], s=5, c='b', alpha=0.1)
plt.xlabel(f'Wavelangth {wl[30]}')
plt.ylabel(f'Wavelangth {wl[80]}')
plt.grid(True)

plt.subplot(1, 2, 2)  
plt.title('Scatterplot of Whitened Data')
plt.scatter(WimList[:,30],WimList[:,80], s=5, c='b', alpha=0.1)
plt.xlabel(f'PC1')
plt.ylabel(f'PC2');
plt.grid(True)

# %%
# add the locations of the three spectra to these plots
plt.figure(figsize=(16,8))

plt.subplot(1, 2, 1)  
plt.title('Scatterplot of Original Data')
plt.scatter(imList[:,30],imList[:,80], s=5, c='b', alpha=0.1)
plt.scatter(imSpec_Gr[30], imSpec_Gr[80], c='g', s=20, label='Image Pixel Grass')
plt.scatter(imSpec_F1[30], imSpec_F1[80], c='r', s=20, label='Image Pixel F1')
plt.scatter(spec_F1[30], spec_F1[80], c='r', s=20, marker='x', label='Library Spectrum F1')
plt.legend()
plt.xlabel(f'Wavelangth {wl[30]}')
plt.ylabel(f'Wavelangth {wl[80]}')
plt.grid(True)

PC1 = 30
PC2 = 61
plt.subplot(1, 2, 2)  
plt.title('Scatterplot of Whitened Data')
plt.scatter(WimList[:,PC1],WimList[:,PC2], s=5, c='b', alpha=0.1)
plt.scatter(WimSpec_Gr[PC1], WimSpec_Gr[PC2], c='g', s=20, label='Image Pixel Grass')
plt.scatter(WimSpec_F1[PC1], WimSpec_F1[PC2], c='r', s=20, label='Image Pixel F1')
plt.scatter(Wspec_F1[PC1], Wspec_F1[PC2], c='r', s=20, marker='x', label='Library Spectrum F1')
plt.legend()
plt.xlabel(f'PC1')
plt.ylabel(f'PC2');
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       5 plt.title('Scatterplot of Original Data')
#       6 plt.scatter(imList[:,30],imList[:,80], s=5, c='b', alpha=0.1)
# ----> 7 plt.scatter(imSpec_Gr[30], imSpec_Gr[80], c='g', s=20, label='Image Pixel Grass')
#       8 plt.scatter(imSpec_F1[30], imSpec_F1[80], c='r', s=20, label='Image Pixel F1')
#       9 plt.scatter(spec_F1[30], spec_F1[80], c='r', s=20, marker='x', label='Library Spectrum F1')
#
# NameError: name 'imSpec_Gr' is not defined

# %% [markdown]
# ## Observation: We often say that 'target detection detects pixels that are way from the mean in whitened-space, but in the direction of the target'. This plot demonstrates that concept.

# %%
i = 5
plt.hist(WimList[:,i].flatten(), bins=100);
plt.title(f'Histogram of Whitened Spectra, Band {i}\n NOTE: This in theory should be a normal distribution.')
# Out:
# Text(0.5, 1.0, 'Histogram of Whitened Spectra, Band 5\n NOTE: This in theory should be a normal distribution.')

# %%
for i in range(3):
    plt.figure()
    plt.imshow(np.reshape(WimList[:,i], (im.nrows,im.ncols)))
    plt.title(f'Whitened Band {i}')

# %% [markdown]
# Fig 4 caption: "Plots of the image data projected from whitened space with false alarms for ACE shown in
#  green. The vertical axis is adjacent side and the horizontal axis is opposite side from Eq. (8). The
#  highest scoring target pixel from the ground truth is shown in red. The false alarms—pixels scoring
#  greater than the highest scoring target pixel from the ground truth—are shown in green. For the
#  fabric panels additional ground truth target pixels are shown in teal. The number of false alarms is
#  provided in the title for each plot."

# %% [markdown]
# hyp = sqrt(X dot X)
# adj = T dot X / sqrt(T dot T)
# opp = sqrt(hyp^2 - adj^2)
# MF = adj/mag(T)

# %%
print(list(enumerate(names)))
# Out:
# [(0, 'V3_field_spectrum'), (1, 'V2a_field_spectrum'), (2, 'V2b_field_spectrum'), (3, 'V1_field_spectrum'), (4, 'F7_field_spectrum'), (5, 'F7_Cloth_Green'), (6, 'F6_field_spectrum'), (7, 'F6_Nylon_Silver'), (8, 'F5_field_spectrum'), (9, 'F5_Nylon_Maroon'), (10, 'F4_field_spectrum'), (11, 'F4_Nylon_Maroon'), (12, 'F3_field_spectrum'), (13, 'F3_Cloth_Blue'), (14, 'F2_field_spectrum'), (15, 'F2_Nylon_Yellow'), (16, 'F1_field_spectrum'), (17, 'F1_Cloth_Red')]

# %%
lib_F1 = spec[17,:]
lib_F2 = spec[15,:]
lib_F3 = spec[13,:]
lib_V1 = spec[3,:]
lib_V2 = spec[1,:]
lib_V3 = spec[0,:]

# %%
sqrt_t_dot_t.shape
# Out:
# (18,)

# %%
adj = x_dot_t / sqrt_t_dot_t
opp = np.sqrt(hyp**2 - adj**2)

# %%
adj.shape
# Out:
# (224000, 18)

# %%
plt.figure(figsize=(16,8))

plt.subplot(1, 2, 1)  
plt.title(f'Scatterplot of {names[17]}')
plt.scatter(opp[:,17],adj[:,17], s=5, c='b', alpha=0.1)
plt.xlabel(f'opp')
plt.ylabel(f'adj')
plt.grid(True)

#
